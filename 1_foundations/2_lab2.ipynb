# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins xxxx
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins xxx
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
print(messages)
# Out:
# [{'role': 'user', 'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are the chief advisor to the democratically elected government of a coastal nation of 4 million people projected to lose 20% of its land area to sea-level rise within 40 years; you have a 15-year window to implement policies with an annual budget equal to 3% of current GDP and the political constraint that all major decisions must be publicly justifiable and protect democratic inclusion. Design a prioritized, phased 15-year plan (annual or clearly divided phases) that: (1) lists concrete actions, responsible agencies, and realistic timelines; (2) specifies objective criteria and a transparent decision framework for which communities to protect in place, which to retreat from, and which to relocate, including how to value cultural sites and nonmarket losses; (3) proposes a detailed budget allocation across coastal defenses, managed retreat and relocation costs, economic resilience programs, social safety nets, and cultural heritage preservation; (4) defines measurable metrics, monitoring protocols, and explicit contingency triggers that would require strategy shifts; (5) explains how you will meaningfully include vulnerable and indigenous communities in decision-making and ensure equity in outcomes; and (6) provides an ethical justification of trade-offs made, a clear statement of key quantitative assumptions, an analysis of main risks and unintended consequences, and an alternate contingency plan for the case that available funding falls by 40% or political support is reduced—please be explicit about all assumptions and show how you would evaluate success over time?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a structured, phased 15-year plan intended for a coastal nation of about 4 million people facing projected 20% land-area loss to sea‑level rise within roughly 40 years. It assumes a constant annual national budget equal to 3% of current GDP (real budget envelope grows with GDP; inflation is managed). The plan prioritizes concrete actions, accountable agencies, transparent decision criteria, equitable participation (including vulnerable and Indigenous communities), and explicit contingencies. All components are designed to be publicly justifiable in democratically elected governance and to protect inclusion and rights.
#
# 1) Baseline assumptions and planning parameters (key numbers used throughout)
# - Time horizon: 15 years, with clearly defined phases (see Phase plan below).
# - Population: ~4,000,000.
# - Land loss risk: up to 20% of current coastal land area affected over 40 years; unevenly distributed (some districts near marshes, outlets, deltas, small island geographies, and specific cultural sites at higher risk).
# - Annual budget envelope: 3% of current GDP. All program budgets are expressed as percentages of GDP for planning; actual annual allocations scale with GDP. For illustration, if GDP ≈ $20B, annual envelope ≈ $600M; if GDP ≈ $25B, ≈ $750M, etc.
# - Core cost categories (illustrative share ranges; sum = 100% of the 3% GDP budget each year):
#   - Coastal defenses and risk reduction (structural and nature-based): 35–45%
#   - Managed retreat and relocation costs: 15–25%
#   - Economic resilience programs (livelihood diversification, fisheries adaptation, tourism resilience, etc.): 15–25%
#   - Social safety nets and transitional supports (income support, unemployment, health access): 8–15%
#   - Cultural heritage preservation and adaptation (digitization, protection, relocation of non-replicable assets, community memory programs): 5–10%
# - Decision framework inputs (data sources): hazard maps, erosion and accretion trends, storm surge risk, population vulnerability, asset exposure, cultural significance, governance capacity, and community consent metrics.
# - Valuation methods for nonmarket losses: contingent valuation, choice experiments, ecosystem services valuation, and culturally informed weightings in a transparent, auditable framework.
# - Governance: a cross-ministerial Inclusive Climate Council (ICC) with explicit FPIC (free, prior, informed consent) processes for Indigenous and vulnerable communities; participatory budgeting elements; independent oversight and public reporting.
#
# 2) Governance, inclusion, and decision framework (how communities participate and how decisions are justified)
# - Participating entities:
#   - Ministries: Environment and Climate Change; Infrastructure and Transport; Urban Development and Housing; Fisheries and Maritime Affairs; Culture; Social Welfare; Indigenous and Cultural Affairs Office.
#   - Independent bodies: National Disaster Risk Management Authority; Coastal Protection Authority; National Statistics Office; an independent Coastal Ethics and Oversight Commission (CEOC) with civil society and Indigenous representation; local government associations; and community advisory councils at district/municipal levels.
# - Meaningful inclusion measures:
#   - Establish Indigenous and vulnerable-community councils with real decision rights in planning areas where they are most affected.
#   - FPIC processes with free, prior, informed consent for relocations or significant land-use changes affecting Indigenous peoples and traditional communities; consent decisions must be revisited if risk assessments change materially.
#   - Gender-responsive budgeting and inclusive participation (women, youth, persons with disabilities, migrant workers).
#   - Transparent public consultation with multilingual channels, public dashboards, and accessible forums (digital and in-person).
#   - Capacity-building funds to support community representatives’ technical understanding of climate risks, land-use planning, and compensation mechanisms.
# - Public justification mechanism:
#   - A publicly accessible, annually updated “Coastline Protection and Relocation Rationale” document explaining phase-by-phase decisions, risk thresholds, equity considerations, and the rationale for protecting in place, retreat, or relocating communities.
#   - A standardized scoring rubric (see Phase plan) used in every major decision, with published data sources and sensitivity analyses.
#
# 3) The 15-year phased plan (actions, agencies, timelines, deliverables)
# Phase A: Phase 0–1 (Year 1–Year 2)
# Objectives: Establish governance, gather baseline data, begin community engagement, and initiate protection pilot zones where risk is highest but cost is feasible.
# Actions and responsibilities
# - Establish ICC and CEOC; appoint executive director; set up public dashboards and data portals.
#   - Responsible: Office of the President/Prime Minister; MEC; Cabinet; CEOC; Civil Society Liaison Office.
# - Comprehensive coastal risk mapping and baseline data collection (topography, land cover, population, critical infrastructure, cultural sites, ecosystem services, nonmarket values).
#   - Responsible: National Statistics Office; MEC; Geological/Coastal Survey agencies; Universities.
# - Begin FPIC processes in high-risk districts; establish district-level Coastal Community Councils with gender-balanced representation.
#   - Responsible: Indigenous and Cultural Affairs Office; Local Governments; ICC.
# - Pilot nature-based defenses (two to four small, community-led dune restoration and mangrove rehabilitation projects) in the highest-risk segments; test “living shoreline” approaches.
#   - Responsible: MEC; Coast Protection Authority; Local Governments; forestry/marine agencies.
# - Establish emergency social safety nets readiness and early warning systems; upgrade meteorological & tide gauge networks.
#   - Responsible: National Disaster Risk Management Authority; Ministry of Social Welfare; MET services.
# - Budget: 3% of GDP; initial allocation ~38–42% to Coastal Defenses (pilot scale), 15–25% to Protection pilots, 10–15% to Risk Mapping and Data Infrastructure, 8–12% to Social Safety Net pilots, 5–8% to Cultural Heritage baseline.
#
# Deliverables
# - Baseline vulnerability and risk maps; publicly accessible data portal.
# - FPIC framework finalized and first rounds of district consultations completed.
# - 2–4 pilot nature-based defense projects operational; performance reports.
# - Early warning and communications upgrade plan completed.
#
# Phase B: Phase 2–Phase 3 (Year 3–Year 6)
# Objectives: Scale up protection where feasible; begin more extensive managed retreat pilots; expand economic resilience and social nets; protect cultural heritage where possible.
# Actions and responsibilities
# - Expand coastal defenses (hybrid approaches: hard defences in high-value zones; nature-based measures in buffer zones; improve drainage and flood-proofing).
#   - Responsible: Coast Protection Authority; Ministry of Infrastructure; Local Governments; Community partners.
# - Implement managed retreat pilots in selected neighbourhoods with clear risk gradients and strong community consent; acquire land or easements where feasible; fund relocation to inland zones with basic services.
#   - Responsible: MUDH; MEC; NDMA; Local Governments; Finance Authority.
# - Inland relocation planning: design and construct inland resettlement sites with utilities, schools, clinics, markets; ensure access to livelihoods (e.g., aquaculture supply chain hubs relocated inland, business incubation).
#   - Responsible: MUDH; Ministry of Culture (heritage integration); Fisheries and Maritime Affairs (livelihood continuity).
# - Economic resilience programs: diversify livelihoods (alternative energy, tourism diversification away from high-risk coastlines, fisheries diversification, cold-chain logistics); microfinance and insurance expansion for coastal workers.
#   - Responsible: Ministry of Economic Affairs; Fisheries and Maritime Affairs; Ministry of Culture; Local Governments.
# - Social safety nets: broaden unemployment benefits, health access, housing assistance during relocation, transitional income supports.
#   - Responsible: Ministry of Social Welfare; Health Ministry; MOF (fiscal authority).
# - Cultural heritage: digital documentation and commemoration of heritage sites; where relocation occurs, plan for on-site archival or relocation of movable heritage; engage communities in protecting intangible heritage (song, language, traditional practices).
#   - Responsible: Ministry of Culture; Indigenous and Cultural Affairs Office; Local Cultural Councils.
# - Monitoring and governance: quarterly risk reviews; public dashboards; annual independent audit on equity outcomes and consent processes.
# - Budget: 3% of GDP; approximate allocation: Coastal Defenses 40–50%, Managed Retreat/Relocation 20–25%, Economic Resilience 15–20%, Social Safety Nets 8–12%, Cultural Heritage 5–7%.
#
# Deliverables
# - Expanded defenses in high-risk zones; retreat pilot communities relocated or legally empowered to move.
# - Inland settlement master plans with infrastructure and livelihood linkages.
# - Livelihood diversification programs scaled; insurance schemes accessible to coastal workers.
# - Digitized cultural heritage records; public-facing heritage archive; community memory initiatives.
#
# Phase C: Phase 4–Phase 5 (Year 7–Year 10)
# Objectives: Consolidate protective measures, scale up relocation where consented and feasible, deepen resilience and economic adaptation, and integrate heritage protection with living communities.
# Actions and responsibilities
# - Scale-up “relocation-forward” where communities express clear consent and risk indicates unsustainable in-situ protection; invest in inland infrastructure and service hubs including healthcare, education, and markets.
# - Harden critical infrastructure (roads, ports, power, water) to support adaptation outcomes; continue integrated water management and flood control; expand natural buffers (reforestation of mangroves, barrier reefs where ecologically appropriate).
# - Strengthen seafood value chains and climate-smart fisheries; promote sustainable tourism that is not exposed to the same coastal hazards (e.g., ecotourism inland or in safer coastal belts).
# - Expand financial mechanisms: resilient investment funds, indexed catastrophe bonds if feasible, micro-insurance for households, floodplain land-use transfer programs with clear titling.
# - Cultural heritage adaptation: maintain on-site protection where feasible; relocate critical artifacts and create living museums where relocation is necessary; ensure language and traditional practices are embedded in inland communities.
# - Equity and governance: ongoing FPIC updates; grievance mechanisms; public reporting and citizen oversight.
# - Budget: 3% of GDP; approximate allocation: Coastal Defenses 25–40%, Managed Retreat/Relocation 25–30%, Economic Resilience 20–25%, Social Safety Nets 8–12%, Cultural Heritage 5–7%.
#
# Deliverables
# - Large-scale protective infrastructure where cost-effective; relocation programs with completed land acquisition or relocation plans; inland service hubs functioning with livelihoods integrated.
# - Strengthened value chains for coastal communities; diversified tourism assets; continuing cultural heritage safeguards.
#
# Phase D: Phase 6–Phase 7 (Year 11–Year 13)
# Objectives: Shift toward long-term resilience, adapt to evolving risk, and ensure sustainable living conditions for relocated and in-place communities; prepare for policy sunset or transition.
# Actions
# - Finalize protection and relocation balance across districts with robust public consent documentation; complete sectoral resilience programs; scale back noncritical investments if risk reduced or budget constrained.
# - Maintain surveillance of coastline changes; adapt defenses to cost-effective upgrades; maintain natural buffers to maximize benefits for ecosystem services.
# - Continue funding for social safety nets and ensure equitable access to opportunities in inland areas (education, healthcare, jobs).
# - Heritage programs: consolidate digital stores, maintain local memory centers, formal recognition of community heritage events, and ensure tourism pipelines support heritage preservation.
# - Budget: 3% of GDP with allocation band tightening as necessary; typical shares: Coastal Defenses 20–35%, Managed Retreat/Relocation 25–35%, Economic Resilience 20–25%, Social Safety Nets 8–12%, Cultural Heritage 5–8%.
#
# Deliverables
# - Sustainable balance of defense and retreat; functioning inland communities with preserved livelihoods; ongoing cultural heritage preservation.
#
# Phase E: Phase 8–Phase 9 (Year 14–Year 15)
# Objectives: Evaluation, adaptation, and policy refinement; plan for steady-state governance of coastline resilience, with clear sunset/transition criteria for future budgets and authorities.
# Actions
# - Final policy evaluation; publish comprehensive 15-year report; update risk maps and land-use plans; set next horizon commitments if needed.
# - Institutionalize ongoing citizen oversight and FPIC processes for any future expansions or reconfigurations.
# - Maintain and improve inland livelihoods; ensure equitable outcomes across communities; finalize cultural heritage integration into inland life.
# - Budget: 3% of GDP but with explicit sunset clauses or transition plans, reflecting the long-term viability and projected risk.
#
# Deliverables
# - Publicly accessible 15-year evaluation and a plan for ongoing adaptation beyond Year 15.
#
# 4) Concrete decision framework for protecting in place vs retreat vs relocation (how to make choices, what inputs are used, and how values are included)
# - Core decision criteria (scored for each district/area using a consistent rubric; 0–5 scale for each criterion; total 0–25 or normalized 0–100):
#   - Hazard exposure: current and projected rate of sea‑level rise, storm surge, erosion, flood depth, salinity intrusion.
#   - Vulnerability: population density, reliance on coastal livelihoods, presence of vulnerable groups, displacement risk.
#   - Asset exposure: value of built infrastructure, healthcare, schools, critical facilities, cultural sites; replacement costs.
#   - Cost of protection: estimated cost of defenses to bring risk to an acceptable level; maintenance costs.
#   - Feasibility: engineering feasibility, land availability for retreat/relocation, governance readiness, local support.
#   - Cultural significance: presence and importance of cultural sites, language and heritage, nonmarket values (identity, memorial values).
#   - Equity/Consent: presence of FPIC or consent from affected communities; potential impact on marginalized groups.
#   - Economic impact: effect on livelihoods (fisheries, tourism, transport); potential for alternative livelihoods.
# - Valuation of nonmarket losses and cultural sites:
#   - Cultural significance scores (qualitative input from Indigenous and community stakeholders) combined with contingent valuation surveys and willingness-to-pay measures for preservation of heritage and cultural memory.
#   - Nonmarket ecosystem services: mangrove buffers, coastal protection, nutrient cycling, biodiversity; monetized via ecosystem-services valuation where possible.
#   - Indirect costs and benefits: social cohesion, mental health, community resilience, and intergenerational equity.
# - Decision rules (summary):
#   - Protect in place if hazard exposure is moderate, economic/strategic assets are high-value, feasibility is high, and cultural sites have strong ties to identity; with consent from affected communities.
#   - Retreat if exposure is high-to-severe, protection costs exceed threshold (set ex ante), land for protections is insufficient or untenable, community consent supports relocation, and alternative livelihoods exist.
#   - Relocate if critical infrastructure or large population centers face high risk, cost of protection is prohibitive, and feasible inland sites with services exist; cultural heritage can be preserved via digitization and on-site relocation where possible.
#
# 5) Budget allocation and financing mechanics
# - Annual envelope: 3% of current GDP.
# - Proposed indicative allocation bands (as percent of GDP per year, to be refined when GDP is known):
#   - Coastal defenses and nature-based defense projects: 35–45%
#   - Managed retreat and relocation costs (acquisition, housing, inland service hubs, compensation): 15–25%
#   - Economic resilience programs (livelihood diversification, fisheries adaptation, climate-smart tourism, value chains): 15–25%
#   - Social safety nets and transition supports: 8–12%
#   - Cultural heritage preservation and adaptation: 5–10%
# - Example (illustrative numbers for a $20B GDP baseline; totals 3% ≈ $600M):
#   - Coastal defenses: $210–$270M (35–45%)
#   - Managed retreat/relocation: $90–$150M (15–25%)
#   - Economic resilience: $90–$150M (15–25%)
#   - Social safety nets: $48–$72M (8–12%)
#   - Cultural heritage: $30–$60M (5–10%)
# - Revenue and finance considerations:
#   - Use a mix of annual appropriations, contingent reserves, and legitimate debt instruments for capital-intensive defenses, with clear debt service costs and sunset/return-to-revenue plans.
#   - Explore blended finance: national funds, climate finance facilities, concessional loans, international grants, and public-private partnerships for selective infrastructure and relocation projects.
#   - Ensure fiscal efficiency with competitive procurement, performance-based contracts, and independent audits.
# - Contingency and scaling:
#   - If GDP growth slows, maintain minimum essential protections for high-risk districts; scale back noncritical activities; retain FPIC and equity commitments.
#   - If political support wanes, lock in core protections and safety nets through legal frameworks and transparent public reporting; emphasize citizen oversight.
#
# 6) Measurable metrics, monitoring protocols, and explicit contingency triggers
# - Metrics (annual and phase-based):
#   - Area protected in place (km2) and population protected; number of communities opting to relocate; number of households supported by relocation or insurance; share of critical infrastructure hardened or relocated; number of cultural sites preserved or digitized; employment diversification metrics; poverty rate changes in coastal regions; health access indicators in inland hubs; public satisfaction and consent rates.
#   - Ecosystem services indicators: coastal buffer integrity, mangrove extent, sediment stability, biodiversity indices.
#   - Financial metrics: annual expenditures by category; cost per person protected or relocated; return on investment for livelihood programs.
#   - Governance metrics: FPIC approvals completed; public dashboards updated; number of independent audits; grievance resolution times.
# - Monitoring protocols:
#   - Independent Coastal Outcomes Commission (ICOC) conducts annual audits of program performance, equity outcomes, and consent processes; publishes a comprehensive public report with data access.
#   - Regular hazard monitoring using national sensors, satellite remote sensing, and ground truthing; quarterly risk-reassessment reports; biannual updates to risk maps.
#   - Community-based monitoring with local councils: monthly reports on local conditions, feedback, and concerns; participatory budgeting updates in each district.
#   - Cultural heritage monitoring: independent heritage assessors assess digitization progress, on-site protection status, and community satisfaction with preservation efforts.
# - Contingency triggers that would require strategy shifts (examples):
#   - Trigger A: Hazard exposure or land loss accelerates beyond modeled scenarios (e.g., actual erosion rates exceed the mid-range model by more than 50% for two consecutive years). Action: pause noncritical relocations, accelerate high-value protections in the worst zones, revisit cost-benefit analysis, and potentially reallocate funds to immediate protections.
#   - Trigger B: Budget under-execution or a funding gap >40% of planned annual appropriation. Action: implement a formal scaled-back plan prioritizing high-risk, high-value protections and safety nets; activate contingency financing plans; pause low-priority projects.
#   - Trigger C: Consent failures or significant opposition to relocation in multiple districts; repeated FPIC revocation or protests with clear risks to social stability. Action: re-engage communities with emphasis on benefit sharing, revise compensation, adjust land-use plans, and potentially defer relocations.
#   - Trigger D: Infrastructure failures or severe disaster events indicating unanticipated risk magnitude (e.g., unprecedented storm surge). Action: immediate protective escalations, emergency funding, and rapid design revisions.
#   - Trigger E: Major macroeconomic shock (double-digit recession sustained for 4 quarters). Action: prioritize safety nets and critical services; defer nonessential capital investments; pursue international climate finance where possible.
#   - Trigger F: Inability to protect or relocate certain communities due to land rights complexities or legal obstacles. Action: implement alternative living arrangements, compensation, or cultural preservation by digitization and memory work, while continuing to pursue resolution.
# - Evaluation of success over time:
#   - Annual public reporting against a core dashboard of coverage (area protected, people protected, number of relocations completed, livelihood outcomes), equity metrics (consent rates, benefits for vulnerable groups), and cultural heritage outcomes (sites preserved/digitized).
#   - Mid-term independent review at Year 7 with a revised plan if necessary (reevaluate risk, costs, consent, and equity outcomes).
#   - Final Year 15 evaluation against baseline and target metrics; publish lessons learned and a recommended long-term governance structure for ongoing coastal resilience with explicit sunset/start-up of a new cycle if needed.
#
# 7) Meaningful inclusion and equity in decision-making (how vulnerable and Indigenous communities are included, and how equity is ensured)
# - FPIC throughout: any decision affecting Indigenous communities or areas with high Indigenous significance requires Free, Prior, Informed Consent; community decisions influence options and cost-sharing structures; consent is revisited if risk or circumstances change materially.
# - Governance inclusion:
#   - Seats for Indigenous representatives and vulnerable community leaders in the ICC and CEOC; district-level community advisory councils with gender and disability representation; youth and fisherfolk representation embedded in decisions affecting livelihoods.
#   - Language access, accessible meetings, and culturally appropriate processes; capacity-building funds to help communities understand trade-offs, costs, and compensation schemes.
# - Equity safeguards:
#   - Equity impact assessments for all major decisions; targeted support for the most vulnerable (low-income households, women, elderly, people with disabilities) during relocation or transition.
#   - Guaranteed livelihood options in inland settlements (jobs, schooling, healthcare, market access) and consistent access to social safety nets for at least a defined transition period.
#   - Transparent grievance mechanisms with independent mediation and appeal processes; clear compensation standards for land acquisitions and livelihood losses.
# - Cultural heritage and Indigenous rights:
#   - Prioritization of preservation and respectful relocation options for heritage and cultural sites; digital archiving and community-led interpretation of heritage; involvement of community guardians in protecting intangible cultural heritage (language, songs, ritual practices).
#
# 8) Ethical justification of trade-offs, key assumptions, risks, and an alternate contingency plan
# - Ethical justification:
#   - Protecting lives, livelihoods, and basic rights in the face of climate risk is a legitimate state obligation in a democracy; actions are designed to minimize coercive displacement, maximize community consent, and provide fair compensation and alternative livelihoods.
#   - The plan prioritizes least-disruption approaches consistent with consent (protect in place where feasible, retreat only where necessary, and relocate with meaningful community input and support). It also prioritizes cultural heritage preservation, memory, and identity as essential components of a just transition.
# - Key quantitative assumptions (explicit):
#   - SLR and hazard projections are based on mid-range IPCC-style scenarios with sensitivity analyses.
#   - 20% of coastal land area is at risk over 40 years; distributions by district follow current exposure patterns; defense costs are within ranges for hybrid nature-based and structural defenses; relocation costs reflect land acquisition, housing, and inland service development.
#   - 3% GDP annual budget envelope with adjustments for inflation; finance costs and debt service considered where capital investments are debt-funded; government will maintain social safety nets to protect vulnerable groups.
#   - Nonmarket losses and cultural values can be quantified via a combination of contingent valuation and ecosystem-service valuation methods, with strong community input to weight cultural factors.
# - Main risks and unintended consequences:
#   - Inequitable outcomes if consent is unevenly achieved, or if relocation creates new forms of marginalization (e.g., in-migration to inland districts overwhelming services).
#   - Economic risks if defense investments fail to deliver expected protection or if relocation disrupts livelihoods without viable alternatives; potential for “double exposure” where defenses induce growth in risky areas.
#   - Environmental risks if hard defenses cause erosion of other areas, degrade natural buffers, or alter sediment transport; ecosystem disruption could occur if nature-based solutions are not properly designed.
#   - Governance and political risks: public trust could erode if costs, benefits, or consent processes appear opaque; delays in land acquisition or permitting could derail timelines.
# - Alternate contingency plan for a 40% funding cut or reduced political support:
#   - Prioritize core safety-net guarantees and high-risk protections; defer nonessential resilience investments; accelerate innovations that deliver high leverage with lower costs (e.g., targeted nature-based approaches, community-led defenses, and low-cost monitoring).
#   - Scale-back relocation by focusing first on districts where risk is highest and consent is strongest; adopt incremental, low-cost relocation options (e.g., shared facilities, phased transitions, and mixed-use inland hubs).
#   - Seek alternative financing: climate finance facilities, international grants, concessional loans, and public-private partnerships for selected high-impact projects with clear risk-sharing and performance metrics.
#   - Strengthen governance and transparency: maintain public dashboards, publish rapid-assessment reports, and maintain a citizen oversight body to sustain legitimacy during constrained periods.
#   - Reassess risk, re-prioritize allocations, and publish an updated, publicly justified plan with revised timelines and targets.
#
# 9) How success would be evaluated and how to adapt over time
# - Short-term (Year 1–Year 3): Baseline risk maps completed; FPIC processes underway; pilot defenses and relocation pilots initiated; dashboards and reporting system operational; pillars of social safety nets established.
# - Medium-term (Year 4–Year 6): Expansion of defenses in high-risk zones; relocation pilots progressing; inland service hubs functional; diversified livelihoods in place; heritage digitization completed for key sites; governance and consent processes institutionalized.
# - Long-term (Year 7–Year 15): Consolidated protective and relocation framework; resilient livelihoods across inland zones; cultural heritage preserved and integrated; risk monitoring and governance sustainability assured; plan for ongoing adaptation beyond Year 15.
# - Success indicators:
#   - Reduced annual exposure and number of people at risk; proportion of critical infrastructure protected or relocated; stable or improving livelihoods in coastal and inland communities; strong indicators of equity (consent rates, participation, and benefits for vulnerable groups); heritage preservation outcomes; public trust and transparent governance metrics.
# - Transparent reporting:
#   - Annual “State of the Coast” report with public dashboards; independent reviews at mid-term and end-term; open data in machine-readable formats to enable external analysis and public scrutiny.
#
# 10) Summary of deliverables and responsibilities by sector
# - Governance and inclusion
#   - ICC, CEOC, FPIC processes, district community councils; public dashboards; independent audits.
# - Engineering and protection
#   - Coastal Protection Authority; Ministry of Infrastructure; local governments; nature-based solution pilots; critical infrastructure upgrades.
# - Relocation and settlements
#   - Ministry of Urban Development and Housing; land acquisition and resettlement planning; inland service hubs; livelihood linkages.
# - Economic resilience and livelihoods
#   - Ministry of Economic Affairs; Fisheries and Maritime Affairs; tourism diversification; insurance and microfinance programs.
# - Social safety nets
#   - Ministry of Social Welfare; health services; affordable housing in inland hubs; social protection programs.
# - Cultural heritage and Indigenous rights
#   - Ministry of Culture; Indigenous and Cultural Affairs Office; heritage digitization; commemorative and memory initiatives; FPIC oversight.
# - Monitoring and accountability
#   - ICOC; National Statistics Office; NDMA; independent auditors; public reporting.
#
# If you would like, I can convert this into a concrete year-by-year action plan with explicit budget lines (in local currency and in terms of GDP percentages), a scoring rubric template for the protection/retreat/relocation decision, and a set of sample dashboards and data requests to share publicly. I can also adapt the plan to a hypothetical GDP figure (e.g., $20B vs. $30B) to illustrate annual budget magnitudes and project costs in more precise terms.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# As Chief Advisor, I present this 15-year plan for our coastal nation of 4 million people, facing the existential threat of losing 20% of its land area to sea-level rise (SLR) within 40 years. This plan is designed to be publicly justifiable, protect democratic inclusion, and leverage our annual budget of 3% of current GDP (approx. $4.8 billion per year).
#
# ---
#
# ### **A Resilient Future: A 15-Year National Adaptation Plan for Sea-Level Rise**
#
# **Core Vision:** To transform our nation into a global leader in climate adaptation, safeguarding our people, culture, and economy through strategic protection, managed retreat, and innovative resilience, ensuring a just and equitable transition for all.
#
# **Guiding Principles:**
# 1.  **People First:** Prioritizing the safety, well-being, and dignity of our citizens.
# 2.  **Justice & Equity:** Fair distribution of burdens and benefits, especially for vulnerable and Indigenous communities.
# 3.  **Transparency & Accountability:** Open decision-making, data-driven policies, and continuous public engagement.
# 4.  **Economic Reinvention:** Building a vibrant, climate-resilient economy that fosters new opportunities.
# 5.  **Cultural Stewardship:** Preserving our unique heritage, both tangible and intangible.
# 6.  **Adaptive Governance:** Flexibility to adjust strategies based on evolving science and on-the-ground realities.
#
# **Contextual Assumptions:**
# *   **Population:** 4 million
# *   **Assumed Current GDP:** $160 Billion (approx. $40,000 per capita)
# *   **Annual Budget Allocation:** 3% of GDP = **$4.8 Billion/year**
# *   **Total 15-Year Budget:** **$72 Billion**
# *   **Sea Level Rise Projection:** High-end scenario, implying an aggressive rate of inundation and erosion, leading to 20% land loss in 40 years.
# *   **Political Will:** Strong initial national consensus and sustained political commitment.
#
# ---
#
# ### **Part 1: Prioritized, Phased 15-Year Plan**
#
# The plan is divided into three 5-year phases, each building upon the previous, with continuous monitoring and adaptation.
#
# **Phase 1: Foundation, Assessment & Pilot Implementation (Years 1-5)**
# *   **Goal:** Establish legal, institutional, and data foundations; foster public understanding and engagement; conduct detailed assessments; initiate pilot projects.
# *   **Annual Budget Allocation:** $4.8 Billion
#
# | Action Area                        | Concrete Actions                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Responsible Agencies                                                                                                                    | Timeline    |
# | :--------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :-------------------------------------------------------------------------------------------------------------------------------------- | :---------- |
# | **1.1 Governance & Legal Framework** | - Establish a **National Coastal Adaptation Authority (NCAA)** as the central coordinating body. <br> - Enact a comprehensive **Coastal Adaptation Act (CAA)**, defining mandates for adaptation, land use, compensation, and eminent domain for retreat. <br> - Amend zoning regulations for "no-build" and "retreat-ready" designations in at-risk areas.                                                                                                            | Ministry of Justice, Ministry of Environment, NCAA (once established), Parliament                                                     | Y1-Y2       |
# | **1.2 Data & Risk Assessment**     | - Conduct high-resolution LiDAR mapping, bathymetric surveys, and dynamic SLR modeling for the entire coastline (priority on high-risk zones). <br> - Map all critical infrastructure, cultural sites, and population density within projected inundation zones. <br> - Establish a national multi-hazard early warning system.                                                                                                                                     | Ministry of Environment, National Geographic Institute, Meteorological Agency, NCAA                                                     | Y1-Y3       |
# | **1.3 Public Engagement & Awareness**| - Launch "Our Shifting Shores" public education campaign (media, schools, community workshops). <br> - Establish **Regional Adaptation Councils (RACs)** with diverse community and Indigenous representation. <br> - Create an interactive online portal for data, planning, and feedback.                                                                                                                                                                           | Ministry of Information, Ministry of Education, NCAA, Local Governments                                                                 | Ongoing (Y1-Y15) |
# | **1.4 Economic & Social Resilience**| - Assess national economic vulnerability to SLR (fisheries, tourism, agriculture, ports). <br> - Initiate pilot skills training programs for emerging green and blue economy sectors. <br> - Develop a national digital infrastructure blueprint to support economic decentralization.                                                                                                                                                                             | Ministry of Economy, Ministry of Labor, NCAA                                                                                            | Y2-Y5       |
# | **1.5 Pilot Projects**             | - Implement 2-3 "Protect in Place" pilot projects (e.g., mangrove restoration, small-scale dykes) in diverse communities. <br> - Execute 1-2 small-scale "Managed Retreat/Relocation" pilot projects, emphasizing voluntary participation, comprehensive compensation, and social support. <br> - Document lessons learned and best practices.                                                                                                                             | NCAA, Ministry of Infrastructure, Local Governments, Community Groups                                                                   | Y3-Y5       |
# | **1.6 Cultural Heritage Mapping**  | - Comprehensive mapping, documentation, and vulnerability assessment of all tangible and intangible cultural sites in threatened zones, in partnership with Indigenous communities. <br> - Develop emergency salvage and preservation protocols.                                                                                                                                                                                                                             | Ministry of Culture, Indigenous Affairs Department, NCAA                                                                                | Y1-Y3       |
#
# **Phase 2: Scaling Up & Major Infrastructure (Years 6-10)**
# *   **Goal:** Implement large-scale adaptation projects; accelerate managed retreat and relocation; bolster economic resilience and social safety nets.
# *   **Annual Budget Allocation:** $4.8 Billion
#
# | Action Area                        | Concrete Actions                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Responsible Agencies                                                                                                                    | Timeline    |
# | :--------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :-------------------------------------------------------------------------------------------------------------------------------------- | :---------- |
# | **2.1 Coastal Defenses (Protect)** | - Begin construction of priority hard defenses (sea walls, surge barriers) for critical economic hubs, major cities, and identified "protect-in-place" communities. <br> - Scale up nature-based solutions (mangrove restoration, coral reefs, dune systems) in suitable areas. <br> - Implement strategic beach nourishment programs.                                                                                                                                      | Ministry of Infrastructure, NCAA, Ministry of Environment                                                                               | Y6-Y10      |
# | **2.2 Managed Retreat & Relocation**| - Initiate the first wave of large-scale, voluntary managed retreat and strategic relocation for identified communities. <br> - Develop "Receiving Communities" with necessary infrastructure and services in designated upland areas. <br> - Establish a national land bank for future relocation and ecosystem restoration. <br> - Provide comprehensive financial, housing, and social support for relocating families and businesses.                                      | NCAA, Ministry of Housing, Ministry of Social Welfare, Local Governments, Land Affairs Agency                                         | Y6-Y10      |
# | **2.3 Economic Transformation**    | - Establish Special Economic Zones (SEZs) in inland areas focused on climate-resilient industries (e.g., advanced manufacturing, agri-tech, renewable energy, sustainable aquaculture). <br> - Provide grants and low-interest loans for businesses to relocate or transition to resilient sectors. <br> - Invest in R&D for climate adaptation technologies.                                                                                                                     | Ministry of Economy, NCAA, National Innovation Agency                                                                                   | Y6-Y10      |
# | **2.4 Social Safety Nets**         | - Expand national social safety nets to cover climate-induced displacement and income loss (e.g., unemployment, housing assistance). <br> - Establish mental health and psychosocial support services for affected communities. <br> - Develop robust educational integration programs for relocated children.                                                                                                                                                             | Ministry of Social Welfare, Ministry of Health, Ministry of Education, NCAA                                                             | Y6-Y10      |
# | **2.5 Cultural Heritage Protection**| - Begin strategic relocation/salvage of highly vulnerable tangible cultural artifacts and archives. <br> - Implement advanced digital preservation of intangible heritage (oral histories, traditions) with community involvement. <br> - Co-design preservation strategies for sacred sites with Indigenous communities.                                                                                                                                              | Ministry of Culture, Indigenous Affairs Department, NCAA, National Archives                                                             | Y6-Y10      |
#
# **Phase 3: Full-Scale Adaptation & Long-Term Transition (Years 11-15)**
# *   **Goal:** Consolidate adaptation efforts, ensure long-term sustainability, and continuously monitor and adjust strategies for enduring resilience.
# *   **Annual Budget Allocation:** $4.8 Billion
#
# | Action Area                        | Concrete Actions                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Responsible Agencies                                                                                                                    | Timeline    |
# | :--------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :---------- |
# | **3.1 Integrated Coastal Management**| - Fully operationalize the NCAA as the primary coordinating body for all adaptation efforts. <br> - Implement adaptive management protocols for all coastal defenses, ensuring maintenance and upgrades based on evolving SLR projections. <br> - Establish a permanent national fund for long-term coastal resilience and emergency response.                                                                                                                             | NCAA, Ministry of Finance                                                                                                               | Y11-Y15     |
# | **3.2 Sustained Retreat & Relocation**| - Continue large-scale managed retreat and strategic relocation, integrating lessons learned from previous phases. <br> - Focus on land-use planning in receiving areas to prevent future displacement. <br> - Conduct post-relocation impact assessments to ensure successful integration and well-being of relocated communities.                                                                                                                                         | NCAA, Ministry of Housing, Local Governments                                                                                            | Y11-Y15     |
# | **3.3 Resilient Economy & Infrastructure**| - Support the full transition of the national economy towards climate-resilient and sustainable sectors. <br> - Invest in resilient infrastructure (e.g., climate-proofed transportation, decentralized energy grids, water systems). <br> - Promote blue/green economy initiatives in newly restored coastal ecosystems.                                                                                                                                             | Ministry of Economy, Ministry of Infrastructure, NCAA                                                                                   | Y11-Y15     |
# | **3.4 Enhanced Social Cohesion**   | - Implement programs to foster social cohesion between original residents and relocated communities. <br> - Develop specific support for elderly, disabled, and other vulnerable groups in the transition process. <br> - Establish permanent, independent grievance mechanisms for adaptation-related issues.                                                                                                                                                              | Ministry of Social Welfare, Local Governments, NCAA                                                                                     | Y11-Y15     |
# | **3.5 Legacy & Future Planning**   | - Establish national memorials and digital archives for lost landscapes and heritage. <br> - Develop a long-term (50-100 year) national vision for a post-SLR resilient nation, including land use and demographic projections. <br> - Continuously update scientific projections and adaptation strategies based on global best practices and local monitoring.                                                                                                              | NCAA, Ministry of Culture, National Planning Commission                                                                                 | Y11-Y15     |
#
# ---
#
# ### **Part 2: Objective Criteria and Transparent Decision Framework**
#
# Decisions to protect, retreat, or relocate are profound. Our framework employs a multi-criteria analysis (MCA) with expert assessment and extensive community consultation, overseen by the NCAA. The weighting of criteria will be finalized through public dialogue.
#
# **Decision Categories:**
# 1.  **Protect in Place (High-Value Retention):** Maintain current location with significant coastal defenses.
# 2.  **Managed Retreat (Strategic Relocation):** Phased, planned movement of communities and infrastructure from vulnerable areas.
# 3.  **Relocate (Urgent Resettlement):** Rapid, complete movement due to immediate threat or unsustainable protection costs.
#
# **Decision Framework Criteria (Illustrative Weighting):**
#
# **I. Quantitative Criteria**
# *   **Risk Exposure (30%):** Rate of inundation/erosion, frequency/intensity of extreme events, threat to critical national infrastructure.
# *   **Economic Viability (25%):** Cost-benefit analysis of protection vs. retreat, economic contribution of the area (GDP, employment), future economic potential.
# *   **Population Density & Vulnerability (20%):** Number of people affected, proportion of vulnerable demographics (elderly, children, low-income, disabled), impact on access to essential services.
#
# **II. Qualitative & Non-Market Criteria**
# *   **Cultural & Heritage Significance (15%):**
#     *   **Tangible Heritage:** Presence of UNESCO sites, national monuments, archaeological sites, sacred spaces.
#     *   **Intangible Heritage:** Unique cultural practices, traditions, oral histories tied to the landscape.
#     *   **Indigenous Community Connection:** Sacred lands, ancestral burial grounds, traditional resource areas.
#     *   **Valuation Methodology:** A multi-pronged approach:
#         *   **Cultural Impact Assessment:** Expert-led, involving cultural and Indigenous leaders to define intrinsic significance and irreplaceability.
#         *   **Contingent Valuation/Stated Preference Surveys:** Gauge societal willingness-to-pay for preservation.
#         *   **Proxy-Based Valuation:** Costs of documentation, relocation/replication (if possible).
#         *   **Irreplaceability Principle:** For sites deemed irreplaceable, preservation (or respectful documentation if impossible) takes precedence over monetary valuation.
# *   **Environmental & Ecosystem Services (10%):** Biodiversity hotspots, value of natural coastal defenses (mangroves, reefs), carbon sequestration, water quality, recreational value.
#
# **Transparent Decision Process:**
# 1.  **Initial Assessment (NCAA & Experts):** Apply criteria to generate initial recommendations.
# 2.  **Community Dialogue (RACs):** Present recommendations to affected communities, integrate local knowledge and concerns.
# 3.  **Cultural & Indigenous Impact Statements:** Co-developed with cultural/Indigenous experts for all options.
# 4.  **Multi-Stakeholder Workshops:** Review the composite picture with all stakeholders.
# 5.  **NCAA Recommendation:** Final recommendation with clear rationale and addressing feedback.
# 6.  **Public Justification & Government Approval:** Submit to Cabinet/Parliament with a comprehensive public report.
#
# ---
#
# ### **Part 3: Detailed Budget Allocation (Annual $4.8 Billion)**
#
# | Category                                   | Annual Allocation (Percentage) | Annual Allocation (USD Billions) | Key Expenditures                                                                                                                                                                                                                                                                                                                                                               |
# | :----------------------------------------- | :----------------------------- | :------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **1. Coastal Defenses**                    | 30%                            | $1.44 Billion                     | - Hard infrastructure (sea walls, surge barriers): 60% <br> - Nature-based solutions (mangrove restoration, coral, dunes, living shorelines): 30% <br> - Strategic beach nourishment: 10% <br> *(Focus on critical economic hubs, major cities, and high-value cultural sites identified for protection)*                                                                    |
# | **2. Managed Retreat & Relocation Costs**  | 25%                            | $1.20 Billion                     | - Property acquisition & compensation (fair market value + premium): 50% <br> - Relocation assistance (moving costs, temporary housing): 15% <br> - Infrastructure development in receiving communities (roads, utilities, schools, healthcare): 25% <br> - Land banking for future relocation & ecological restoration: 10%                                                   |
# | **3. Economic Resilience Programs**        | 20%                            | $0.96 Billion                     | - Business relocation grants & low-interest loans: 30% <br> - Skills development & retraining programs: 25% <br> - Investment in climate-resilient industries (agri-tech, renewable energy, sustainable tourism, aquaculture): 30% <br> - Digital infrastructure development & support for remote work: 15%                                                                   |
# | **4. Social Safety Nets & Community Support**| 15%                            | $0.72 Billion                     | - Expanded unemployment & housing assistance for displaced populations: 40% <br> - Mental health and psychosocial support services: 20% <br> - Educational integration for relocated children: 15% <br> - Community engagement, dialogue platforms, and grievance mechanisms: 15% <br> - Support for vulnerable groups (elderly, disabled): 10%                               |
# | **5. Cultural Heritage Preservation**      | 5%                             | $0.24 Billion                     | - Documentation & digital archiving (tangible & intangible heritage): 40% <br> - Physical relocation/salvage of artifacts & movable structures: 30% <br> - Indigenous-led preservation initiatives & sacred site stewardship: 20% <br> - Research & capacity building for cultural heritage adaptation: 10%                                                              |
# | **6. Research, Monitoring & Governance**   | 5%                             | $0.24 Billion                     | - High-resolution mapping & SLR modeling updates: 25% <br> - Environmental monitoring & impact assessment: 25% <br> - NCAA operational costs & regional offices: 25% <br> - Public awareness campaigns & educational materials: 15% <br> - International collaboration & knowledge sharing: 10%                                                                         |
# | **TOTAL**                                  | **100%**                       | **$4.80 Billion**                  |                                                                                                                                                                                                                                                                                                                                                                            |
#
# ---
#
# ### **Part 4: Measurable Metrics, Monitoring Protocols, and Contingency Triggers**
#
# **Measurable Metrics (Key Performance Indicators - KPIs):**
#
# *   **Environmental/Physical:** Hectares of land protected, hectares of ecosystems restored, % reduction in economic losses from coastal hazards, % vulnerable population covered by EWS, change in groundwater salinity.
# *   **Socio-Economic:** Number of people successfully relocated (voluntary/involuntary breakdown), % satisfaction of relocated households, % increase in GDP from resilient sectors, % change in employment rates, % of relocated population with equitable access to services, % reduction in poverty among coastal communities.
# *   **Governance & Equity:** Number of public consultations, % participation rate, % of community feedback integrated, number of Indigenous-led projects, % of traditional knowledge integrated, transparency index score, % grievance resolution rate.
# *   **Cultural Heritage:** Number of cultural sites/practices documented, % of threatened artifacts salvaged, number of sacred sites protected or symbolically marked.
#
# **Monitoring Protocols:**
#
# *   **Annual Progress Reports:** NCAA to Parliament and public.
# *   **Independent Audits:** Every 3 years for financial and program effectiveness.
# *   **Citizen Science & Participatory Monitoring:** Empowering communities to collect data and provide feedback.
# *   **Scientific Review Panels:** Regular review (every 2-3 years) by national and international experts.
# *   **Community Satisfaction Surveys:** Biennial surveys for well-being and perceived fairness.
#
# **Explicit Contingency Triggers for Strategy Shifts:**
#
# *   **Trigger 1: Accelerated SLR:** If observed or projected SLR exceeds current high-end scenarios by **>15%** over 5 years.
#     *   **Shift:** Re-evaluate all "protect in place" decisions, accelerate managed retreat, increase emergency preparedness, redesign coastal defenses.
# *   **Trigger 2: Funding Shortfall:** If the annual budget consistently falls below **80%** of allocation for two consecutive years.
#     *   **Shift:** Prioritize critical protection and urgent relocation; scale back economic and social programs; intensify international funding appeals. (See alternate plan for 40% cut).
# *   **Trigger 3: Major Social Unrest/Low Public Trust:** If community satisfaction surveys indicate **<60% approval** for policies or widespread non-compliance.
#     *   **Shift:** Independent review of decision processes; increased investment in dialogue; revise compensation/support; strengthen grievance mechanisms; potential pause on contentious projects.
# *   **Trigger 4: Ineffective Defenses:** If a protected area experiences **two significant breaches** or sustained damage within 5 years.
#     *   **Shift:** Reassess "protect in place" viability for that area, initiate planning for managed retreat.
# *   **Trigger 5: Major Economic Disruption:** If GDP contracts by **>5%** for two consecutive years, significantly impacting the budget.
#     *   **Shift:** Reallocate resources to core safety nets and critical infrastructure; scale back non-essential programs; focus on rapid job creation.
#
# ---
#
# ### **Part 5: Meaningful Inclusion and Equity**
#
# Democratic inclusion and equity are central to this plan.
#
# **1. Empowering Vulnerable and Indigenous Communities:**
# *   **Dedicated Representation:** Mandate direct, appointed seats for Indigenous communities and vulnerable groups on the NCAA and all RACs, with voting power.
# *   **Indigenous Knowledge Co-Creation:** Establish an "Indigenous Wisdom Council" within NCAA to integrate Traditional Ecological Knowledge (TEK) into all planning phases. Fund Indigenous-led research.
# *   **Culturally Appropriate Engagement:** Multi-lingual materials (including Indigenous languages), accessible meeting formats, and culturally sensitive facilitators.
# *   **Self-Determination:** Respect Indigenous communities' right to self-determination regarding relocation sites, community design, and governance.
# *   **Capacity Building:** Fund training for community leaders in negotiation and policy analysis.
#
# **2. Ensuring Equity in Outcomes:**
# *   **Fair & Just Compensation:** Property compensation includes fair market value *plus* a premium for disruption and cultural attachment. Valuations will consider non-market losses (livelihoods, community networks) in consultation with affected communities. Tiered support packages will assist vulnerable groups.
# *   **"Build Back Better" for Relocated Communities:** Ensure access to equivalent or superior services (schools, healthcare, utilities) in new locations, alongside economic opportunities and funding for new community spaces.
# *   **Protection of Rights:** Provide legal aid services to all affected citizens.
# *   **Monitoring Equity Gaps:** Disaggregated data collection (by income, ethnicity, age, gender) to track outcomes and address disparities. Conduct regular equity audits.
# *   **Grievance and Appeals Process:** Establish a clear, accessible, independent, and timely mechanism for individuals/communities to appeal decisions.
#
# ---
#
# ### **Part 6: Ethical Justification, Assumptions, Risks, and Contingency Plan**
#
# **Ethical Justification of Trade-offs:**
# The plan navigates the difficult balance between preserving the present and securing the future. It is grounded in:
# *   **Utilitarianism:** Maximizing the long-term well-being and security for the greatest number of citizens by preventing catastrophic, unmanaged displacement and economic collapse.
# *   **Distributive Justice:** Ensuring that the burdens of adaptation are not disproportionately borne by the most vulnerable, through fair compensation, targeted support, and equitable access to resources.
# *   **Respect for Human Rights & Dignity:** Upholding democratic inclusion, self-determination, and comprehensive support throughout the transition process, even when difficult decisions are made.
# *   **Intergenerational Equity:** Investing significantly now to safeguard a resilient and prosperous future for generations to come.
#
# The choice to strategically retreat from certain areas is an ethical imperative driven by scientific reality, prioritizing safety and national sustainability over maintaining an untenable status quo.
#
# **Key Quantitative Assumptions:**
# *   **Stable GDP Growth:** Assumed for budget calculation. Significant unpredicted economic contraction would impact funding.
# *   **SLR Projections Accuracy:** Relies on high-end scientific projections; deviations would necessitate adjustments.
# *   **Cost Estimates:** Based on global benchmarks; actual costs may vary due to inflation, material availability, and unforeseen challenges.
# *   **Coastal Population Concentration:** Assumes a significant portion of the population resides in coastal areas, justifying the national scale of intervention.
# *   **Technology Availability:** Assumes current and emerging adaptation technologies remain available and effective.
#
# **Main Risks and Unintended Consequences:**
# *   **Political Instability:** Shifting political priorities, public backlash against difficult decisions, or populist movements.
#     *   **Mitigation:** Continuous public engagement, transparency, cross-party consensus, and tangible benefit demonstration.
# *   **Funding Volatility:** Economic downturns or other national priorities diverting funds.
#     *   **Mitigation:** Diversify funding (green bonds, international climate finance), establish dedicated fund.
# *   **Social Dislocation & Loss of Identity:** Relocation can lead to loss of community ties, livelihoods, and cultural identity.
#     *   **Mitigation:** Psychosocial support, community-led planning, cultural preservation, new community networks, economic integration.
# *   **Unequal Outcomes:** Despite equity efforts, vulnerable groups could still face disproportionate burdens.
#     *   **Mitigation:** Disaggregated data monitoring, independent equity audits, strong legal protections, empowered advocacy.
# *   **Maladaptation:** Solutions failing or creating new problems (e.g., hard defenses starving adjacent beaches).
#     *   **Mitigation:** Best available science, adaptive management, extensive environmental impact assessments, independent expert review.
# *   **Brain Drain:** Loss of skilled labor if economic opportunities are not effectively transitioned.
#     *   **Mitigation:** Proactive economic development, education, training, and incentives.
# *   **Land Speculation:** Exploitation of retreat zones for financial gain.
#     *   **Mitigation:** Strict land use planning, public land banking, anti-speculation laws.
#
# **Alternate Contingency Plan (40% Funding Cut or Reduced Political Support):**
#
# If annual funding falls by **40%** (to $2.88 Billion) or political support significantly diminishes, the plan must pivot to a survival-focused approach.
#
# *   **Re-prioritization Logic:** Shift from "optimize for long-term resilience and equity" to "minimize immediate human suffering and safeguard critical national functions."
# *   **Strategic Adjustments:**
#     *   **Coastal Defenses:** Limit to absolutely essential infrastructure protecting national strategic assets (capital city, primary port, power generation). Halt new large-scale hard defense projects. Prioritize cost-effective nature-based solutions.
#     *   **Managed Retreat & Relocation:** Prioritize only communities in imminent danger or those with the highest vulnerability/lowest relocation cost. Voluntary aspects would be curtailed, shifting towards more directive, though compensated, processes.
#     *   **Minimalist Relocation Support:** Compensation would shift from "fair market value + premium" to "fair market value only" or basic housing and livelihood support. Social safety nets would focus on emergency aid.
#     *   **Economic Programs:** Focus on essential retraining for displaced populations. Halt grants for new climate-resilient industries.
#     *   **Cultural Heritage:** Focus solely on digital documentation and emergency salvage of irreplaceable items. Long-term preservation deferred.
#     *   **Leaner Governance:** Significant reduction in NCAA staffing and outreach, focusing on core coordination and emergency response.
# *   **Ethical Implications:** This contingency would necessitate starker trade-offs, prioritizing survival and minimizing harm over optimal well-being and comprehensive equity. It acknowledges that not everyone can be helped equally when resources are severely constrained, shifting towards a **Triage** ethical framework.
# *   **Evaluation of Success in Contingency:** Success would be redefined as minimizing loss of life, maintaining basic governance, preventing widespread social collapse, and protecting core national assets. Metrics would focus on humanitarian aid delivery, lives saved, and maintenance of essential services.
#
# **How to Evaluate Success Over Time:**
#
# Evaluation is continuous, iterative, and adaptive across all phases:
#
# *   **Short-Term (Years 1-5):** Success is judged by establishing foundational elements: legal frameworks enacted, NCAA operational, high-res mapping completed (e.g., 90% coverage), public awareness increased (e.g., 70% understanding), pilot projects initiated, and community feedback integrated.
#     *   **Evaluation:** Annual NCAA reports, parliamentary oversight, public satisfaction surveys on information dissemination.
# *   **Mid-Term (Years 6-10):** Success is judged by scaling up implementation and showing initial impact: X communities protected/relocated, Y hectares defended, Z jobs created, Q% reduction in displacement-related poverty, cultural sites digitally documented.
#     *   **Evaluation:** Biennial independent audits, scientific review panels, community outcome surveys (relocation satisfaction, access to services), economic impact assessments.
# *   **Long-Term (Years 11-15 & Beyond):** Success is judged by achieving sustainable resilience and a transformed nation: overall reduction in vulnerability (e.g., 50% less population at high risk than baseline), sustained economic growth in climate-resilient sectors, high social cohesion in new communities, all critical cultural heritage protected or documented, and enhanced national capacity to adapt to future SLR.
#     *   **Evaluation:** Comprehensive 15-year plan review against original objectives, independent socio-economic and environmental impact studies, comparison with international best practices, long-term well-being indicators, and intergenerational equity assessments.
#
# This adaptive approach ensures that our nation remains agile and effective in confronting the ongoing challenge of sea-level rise, building a resilient and equitable future for all.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "gemma3:1b-it-qat"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Okay, here’s a detailed, phased 15-year plan designed to address the projected loss of land area due to sea-level rise in a 4 million population coastal nation, prioritizing democratic inclusion, public justification, and long-term resilience. This plan acknowledges the complexity, the need for adaptation, and leverages a cautious, proactive approach.
#
# **I. Executive Summary:**
#
# This plan acknowledges the escalating threat of sea-level rise and aims to mitigate its worst effects through a multi-pronged approach prioritizing community protection, economic stability, cultural preservation, and social equity.  The $3% of GDP annual budget is a realistic constraint, requiring careful prioritization and strategic allocation.  Transparency and public justification are fundamental.  Success is measured through a combination of quantifiable metrics, rigorous monitoring, and flexible contingency plans.
#
# **II. Prioritized Phased Plan (15 Years)**
#
# **Phase 1: Assessment & Initial Response (Years 1-3) – $1.5 Billion (Approx. 20% - Adjust Based on Initial Data)**
#
# *   **Goal:** Establish a baseline understanding, initiate immediate protective measures, and build initial community trust.
# *   **Actions:**
#     *   **Coastal Mapping & Vulnerability Assessment (Q1-Q3):**  Deploy drones and GIS specialists to create detailed maps of vulnerable coastal areas, identifying specific risks (e.g., erosion patterns, high-risk zones). Conduct detailed socio-economic assessments of affected communities.
#     *   **Emergency Resilience Infrastructure (Q2-Q4):**  Establish regional, localized flood defenses (levees, seawalls – prioritizing strategic placement to minimize negative impacts on farmland and critical infrastructure).  Create early warning systems.
#     *   **Community Engagement & Education (Q1-Q3):**  Launch town hall meetings, online forums, and public awareness campaigns promoting climate adaptation and relocation strategies.  Focus on communicating the potential impacts clearly and empathetically.
#     *   **Initial Retreat Planning (Q3-Q4):**  Form a stakeholder panel consisting of representatives from local governments, communities, environmental experts, and economists to establish the initial scale of retreat zones and develop specific relocation strategies.
# *   **Objective Criteria:**  Documented vulnerability assessments; initial flood defense infrastructure presence; baseline understanding of community priorities; community engagement levels.
# *   **Decision Framework:**  Weighted scoring based on risk assessment, social impact, economic necessity, and community consensus.  Transparency in assessment methodology.
# *   **Budget Allocation:**  $600 Million – Emergency response, mapping, initial defenses, education, and relocation planning.
#
# **Phase 2:  Strategic Retreat & Economic Transition (Years 4-7) – $3 Billion (Approx. 40% - Adjust Based on Retreat Impact)**
#
# *   **Goal:**  Reduce vulnerability through targeted retreat, facilitate economic diversification, and address social impacts.
# *   **Actions:**
#     *   **Targeted Retreat Implementation (Q1-Q4):**  Implement relocation plans for the most vulnerable populations based on the previous phase’s findings and updated projections. Prioritize communities with higher concentrations of vulnerable populations and critical infrastructure.  Focus on creating “smart” retreats – resilient but adaptable communities.
#     *   **Economic Diversification Support (Q1-Q4):**  Provide grants and tax incentives to businesses that relocate or adopt new industries.  Offer vocational training programs to support this transition. Focus on sustainable tourism, aquaculture, and new green technologies.
#     *   **Land Use Planning Updates (Q2-Q4):**  Re-evaluate land use regulations – moving away from continuous coastal development towards zones with higher natural vegetation cover and protection.
#     *   **Social Safety Net Enhancement (Q2-Q4):**  Strengthen social safety net programs (food assistance, housing assistance, healthcare) to support those displaced or struggling to adapt.  Ensure culturally appropriate support systems.
# *   **Objective Criteria:**  Reduced population density in retreat zones; demonstrable economic growth within relocated areas; progress towards social safety net adequacy.
# *   **Decision Framework:**  Focus on “just” – equitable distribution of resources across affected communities. Transparency linked to equitable restoration and cultural preservation.  Regular feedback and review from impacted groups.
# *   **Budget Allocation:** $1.75 Billion – Relocation assistance, economic transition funds, support services, environmental restoration.
#
# **Phase 3: Adaptive Resilience & Long-Term Planning (Years 8-12) – $1.2 Billion (Approx. 30% - Adjusted based on retreat impacts)**
#
# *   **Goal:** Optimize adaptation strategies, implement long-term infrastructure, and deepen community engagement.
# *   **Actions:**
#     *   **Adaptation Infrastructure – Smart Coastal Barriers (Q1-Q4):** Focus on adaptive sea defenses (drones, modular flood barriers) that can be adjusted and maintained based on data.
#     *   **Climate-Resilient Agriculture (Q1-Q4):** Invest in supporting local, sustainable agricultural practices – aquaculture, seaweed farming, micro-nutrient agriculture – to build economic resilience.
#     *    **Cultural Heritage Protection (Q2-Q4):** Establish a dedicated safeguarding fund, collaborate with local experts to catalog and document heritage sites.
#     *    **Community Consultation (Ongoing):** Implement regular, transparent community consultations on all long-term adaptation plans.
# *   **Objective Criteria:**   Reduced risk of climate impacts; successful implementation of adaptation plans; sustained community engagement.
# *   **Decision Framework:**  Emphasis on “win-win” – prioritizing sustainability and cultural preservation, promoting co-benefits of adaptation.
# *   **Budget Allocation:** $1.05 Billion – Adaptation infrastructure, land use planning, economic resilience projects, cultural heritage conservation, and ongoing community engagement.
#
# **Phase 4:  Monitoring & Adaptive Management (Years 13 - 15) – $400 Million (Highly Variable)**
#
# *   **Goal:**  Continuously evaluate effectiveness, refine strategies, and address unforeseen challenges.
# *   **Actions:**
#     *   **Systematic Data Collection & Analysis (Ongoing):**  Establish a robust monitoring system (satellite imagery, sensor networks, citizen science) to track sea-level rise, erosion rates, and community wellbeing.
#     *   **Regular Performance Reviews (Quarterly):** Assess progress against goals using key metrics (population shifts, economic indicators, environmental health indicators).
#     *   **Policy Adjustments based on Lessons Learned (Quarterly):** Adapting policies and strategies based on data and feedback.
# *   **Objective Criteria:**  Consistent measure of resilience and adaptability; favorable performance indicators related to ecological health and quality of life.
# *   **Decision Framework:**  Agile and responsive – prioritize rapid adjustments based on evolving data and risks.  Develop a clearly defined “exit strategy” outlining how the plan will be reevaluated and adjusted based on emergent circumstances.
# *   **Budget Allocation:**  $400 million -  to track, analyze, and optimize, reliant on continued funding and support.
#
# **III. Detailed Budget Breakdown (Illustrative)**
#
# *   **Emergency Response:** $500 million (Initial preparedness, flood control, emergency shelters)
# *   **Re-location Support:** $200 million (Relocation assistance, workforce training, housing)
# *   **Economic Transition:** $1.5 Billion (Diversification programs, training)
# *   **Climate Adaptation Infrastructure:** $750 million (Adaptive defenses, coastal restoration)
# *   **Cultural Heritage Preservation:** $150 million (Documentation, restoration, community engagement)
# *   **Social Safety Nets:** $300 million (Food security, housing, healthcare)
# *   **Monitoring & Evaluation:** $100 million (Data collection, analysis, reporting)
#
# **IV. Key Metrics & Monitoring Protocols:**
#
# *   **Projections:** Develop detailed, conservative and optimistic projections for population shifts, economic decline, and environmental changes.  Regularly update these projections based on new data.
# *   **Key Indicators:**
#     *   **Sea Level Rise:** Track and monitor sea level rise levels across the predicted vulnerable zones.
#     *   **Population Mobility:** Monitor the number of people moving into and out of protected and relocated areas.
#     *   **Economic Activity:**  Track the economic output and employment rates in relocated areas and areas experiencing retreat.
#     *   **Environmental Health:** Assess air and water quality, biodiversity, and coastal habitat health.
#     *   **Social Capital:** Track community cohesion, social services utilization, and mental health outcomes.
#
# **V. Contingency Planning – 40% Funding Fall**
#
# *   **Scenario 1: 40% Funding Reduction:** Re-prioritize spending to focus on immediate emergency response and strengthening existing resilience measures.  Reduce the scope of relocations.
# *   **Scenario 2: Political Support Reduction:**  Develop a gradual, transparent, and publicly validated exit strategy with clearly defined milestones and potential reassessment criteria.
# *   **Scenario 3:  Shifted Priorities:** Re-evaluate the entire plan to shift resources towards areas with higher resilience potential or those directly impacting vulnerable communities.
#
#
# **VI. Ethical Justification & Key Assumptions:**
#
# *   **Equity:**  A central priority is equitable distribution of resources and benefits across different communities. This will be achieved through:
#     *   **Community Consultation:** Regular, transparent consultations with affected communities are paramount.
#     *   **Data-Driven Justification:** Decision-making will be informed by rigorous data on the impacts of sea-level rise on diverse populations and ecosystems.
#     *   **Prioritize vulnerable populations:**  Retreat and relocation prioritizations will be directed toward those most at risk.
# *   **Cultural Respect:**  Traditional knowledge and cultural heritage are vital for community resilience and adaptation.  Respect will be given to Indigenous communities’ traditional knowledge and ways of life in all planning decisions. Collaborative frameworks will be developed with indigenous groups.
# *   **Transparency:** Open communication and public access to information will be maintained.
#
#
# **VII. Risk & Unintended Consequences:**
#
# *   **Social Disruptions:**  Large-scale displacement could create social unrest and conflict.
# *   **Economic Hardship:**  Economic losses from retreat and relocation could exacerbate existing inequalities.
# *   **Environmental Degradation:**  Rapid retreat could lead to irreversible damage to ecosystems.
# *   **Increased Migration:** Large-scale migration could strain social services and infrastructure.
#
# **VIII. Evaluation & Success Metrics:**
#
# *   **Quantitative:**  Reduction in flood damage, improvement in population density, recovery of key ecosystem services (e.g., fisheries, agriculture), improvement in community wellbeing ratings.
# *   **Qualitative:**  Documented community narratives, stakeholder satisfaction surveys, data on resilience building, and adoption of new technologies.
#
# **This plan is a framework and will require constant adaptation and refinement based on ongoing data and adaptive learning.**
#
# ---
#
# This detailed plan aims for comprehensive planning, prioritizing the well-being of the most vulnerable, while acknowledging the urgency of climate change.  It acknowledges the complexities of coastal resilience through thoughtful planning, focused resource allocation, and the incorporation of cultural sensitivity and community ownership.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'gemini-2.5-flash', 'gemma3:1b-it-qat']
# ['Below is a structured, phased 15-year plan intended for a coastal nation of about 4 million people facing projected 20% land-area loss to sea‑level rise within roughly 40 years. It assumes a constant annual national budget equal to 3% of current GDP (real budget envelope grows with GDP; inflation is managed). The plan prioritizes concrete actions, accountable agencies, transparent decision criteria, equitable participation (including vulnerable and Indigenous communities), and explicit contingencies. All components are designed to be publicly justifiable in democratically elected governance and to protect inclusion and rights.\n\n1) Baseline assumptions and planning parameters (key numbers used throughout)\n- Time horizon: 15 years, with clearly defined phases (see Phase plan below).\n- Population: ~4,000,000.\n- Land loss risk: up to 20% of current coastal land area affected over 40 years; unevenly distributed (some districts near marshes, outlets, deltas, small island geographies, and specific cultural sites at higher risk).\n- Annual budget envelope: 3% of current GDP. All program budgets are expressed as percentages of GDP for planning; actual annual allocations scale with GDP. For illustration, if GDP ≈ $20B, annual envelope ≈ $600M; if GDP ≈ $25B, ≈ $750M, etc.\n- Core cost categories (illustrative share ranges; sum = 100% of the 3% GDP budget each year):\n  - Coastal defenses and risk reduction (structural and nature-based): 35–45%\n  - Managed retreat and relocation costs: 15–25%\n  - Economic resilience programs (livelihood diversification, fisheries adaptation, tourism resilience, etc.): 15–25%\n  - Social safety nets and transitional supports (income support, unemployment, health access): 8–15%\n  - Cultural heritage preservation and adaptation (digitization, protection, relocation of non-replicable assets, community memory programs): 5–10%\n- Decision framework inputs (data sources): hazard maps, erosion and accretion trends, storm surge risk, population vulnerability, asset exposure, cultural significance, governance capacity, and community consent metrics.\n- Valuation methods for nonmarket losses: contingent valuation, choice experiments, ecosystem services valuation, and culturally informed weightings in a transparent, auditable framework.\n- Governance: a cross-ministerial Inclusive Climate Council (ICC) with explicit FPIC (free, prior, informed consent) processes for Indigenous and vulnerable communities; participatory budgeting elements; independent oversight and public reporting.\n\n2) Governance, inclusion, and decision framework (how communities participate and how decisions are justified)\n- Participating entities:\n  - Ministries: Environment and Climate Change; Infrastructure and Transport; Urban Development and Housing; Fisheries and Maritime Affairs; Culture; Social Welfare; Indigenous and Cultural Affairs Office.\n  - Independent bodies: National Disaster Risk Management Authority; Coastal Protection Authority; National Statistics Office; an independent Coastal Ethics and Oversight Commission (CEOC) with civil society and Indigenous representation; local government associations; and community advisory councils at district/municipal levels.\n- Meaningful inclusion measures:\n  - Establish Indigenous and vulnerable-community councils with real decision rights in planning areas where they are most affected.\n  - FPIC processes with free, prior, informed consent for relocations or significant land-use changes affecting Indigenous peoples and traditional communities; consent decisions must be revisited if risk assessments change materially.\n  - Gender-responsive budgeting and inclusive participation (women, youth, persons with disabilities, migrant workers).\n  - Transparent public consultation with multilingual channels, public dashboards, and accessible forums (digital and in-person).\n  - Capacity-building funds to support community representatives’ technical understanding of climate risks, land-us ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Below is a structured, phased 15-year plan intended for a coastal nation of about 4 million people facing projected 20% land-area loss to sea‑level rise within roughly 40 years. It assumes a constant annual national budget equal to 3% of current GDP (real budget envelope grows with GDP; inflation is managed). The plan prioritizes concrete actions, accountable agencies, transparent decision criteria, equitable participation (including vulnerable and Indigenous communities), and explicit contingencies. All components are designed to be publicly justifiable in democratically elected governance and to protect inclusion and rights.
#
# 1) Baseline assumptions and planning parameters (key numbers used throughout)
# - Time horizon: 15 years, with clearly defined phases (see Phase plan below).
# - Population: ~4,000,000.
# - Land loss risk: up to 20% of current coastal land area affected over 40 years; unevenly distributed (some districts near marshes, outlets, deltas, small island geographies, and specific cultural sites at higher risk).
# - Annual budget envelope: 3% of current GDP. All program budgets are expressed as percentages of GDP for planning; actual annual allocations scale with GDP. For illustration, if GDP ≈ $20B, annual envelope ≈ $600M; if GDP ≈ $25B, ≈ $750M, etc.
# - Core cost categories (illustrative share ranges; sum = 100% of the 3% GDP budget each year):
#   - Coastal defenses and risk reduction (structural and nature-based): 35–45%
#   - Managed retreat and relocation costs: 15–25%
#   - Economic resilience programs (livelihood diversification, fisheries adaptation, tourism resilience, etc.): 15–25%
#   - Social safety nets and transitional supports (income support, unemployment, health access): 8–15%
#   - Cultural heritage preservation and adaptation (digitization, protection, relocation of non-replicable assets, community memory programs): 5–10%
# - Decision framework inputs (data sources): hazard maps, erosion and accretion trends, storm surge risk, population vulnerability, asset exposure, cultural significance, governance capacity, and community consent metrics.
# - Valuation methods for nonmarket losses: contingent valuation, choice experiments, ecosystem services valuation, and culturally informed weightings in a transparent, auditable framework.
# - Governance: a cross-ministerial Inclusive Climate Council (ICC) with explicit FPIC (free, prior, informed consent) processes for Indigenous and vulnerable communities; participatory budgeting elements; independent oversight and public reporting.
#
# 2) Governance, inclusion, and decision framework (how communities participate and how decisions are justified)
# - Participating entities:
#   - Ministries: Environment and Climate Change; Infrastructure and Transport; Urban Development and Housing; Fisheries and Maritime Affairs; Culture; Social Welfare; Indigenous and Cultural Affairs Office.
#   - Independent bodies: National Disaster Risk Management Authority; Coastal Protection Authority; National Statistics Office; an independent Coastal Ethics and Oversight Commission (CEOC) with civil society and Indigenous representation; local government associations; and community advisory councils at district/municipal levels.
# - Meaningful inclusion measures:
#   - Establish Indigenous and vulnerable-community councils with real decision rights in planning areas where they are most affected.
#   - FPIC processes with free, prior, informed consent for relocations or significant land-use changes affecting Indigenous peoples and traditional communities; consent decisions must be revisited if risk assessments change materially.
#   - Gender-responsive budgeting and inclusive participation (women, youth, persons with disabilities, migrant workers).
#   - Transparent public consultation with multilingual channels, public dashboards, and accessible forums (digital and in-person).
#   - Capacity-building funds to support community representatives’ technical understanding of climate risks, land-use planning, and compensation mechanisms.
# - Public justification mechanism:
#   - A publicly accessible, annually updated “Coastline Protection and Relocation Rationale” document explaining phase-by-phase decisions, risk thresholds, equity considerations, and the rationale for protecting in place, retreat, or relocating communities.
#   - A standardized scoring rubric (see Phase plan) used in every major decision, with published data sources and sensitivity analyses.
#
# 3) The 15-year phased plan (actions, agencies, timelines, deliverables)
# Phase A: Phase 0–1 (Year 1–Year 2)
# Objectives: Establish governance, gather baseline data, begin community engagement, and initiate protection pilot zones where risk is highest but cost is feasible.
# Actions and responsibilities
# - Establish ICC and CEOC; appoint executive director; set up public dashboards and data portals.
#   - Responsible: Office of the President/Prime Minister; MEC; Cabinet; CEOC; Civil Society Liaison Office.
# - Comprehensive coastal risk mapping and baseline data collection (topography, land cover, population, critical infrastructure, cultural sites, ecosystem services, nonmarket values).
#   - Responsible: National Statistics Office; MEC; Geological/Coastal Survey agencies; Universities.
# - Begin FPIC processes in high-risk districts; establish district-level Coastal Community Councils with gender-balanced representation.
#   - Responsible: Indigenous and Cultural Affairs Office; Local Governments; ICC.
# - Pilot nature-based defenses (two to four small, community-led dune restoration and mangrove rehabilitation projects) in the highest-risk segments; test “living shoreline” approaches.
#   - Responsible: MEC; Coast Protection Authority; Local Governments; forestry/marine agencies.
# - Establish emergency social safety nets readiness and early warning systems; upgrade meteorological & tide gauge networks.
#   - Responsible: National Disaster Risk Management Authority; Ministry of Social Welfare; MET services.
# - Budget: 3% of GDP; initial allocation ~38–42% to Coastal Defenses (pilot scale), 15–25% to Protection pilots, 10–15% to Risk Mapping and Data Infrastructure, 8–12% to Social Safety Net pilots, 5–8% to Cultural Heritage baseline.
#
# Deliverables
# - Baseline vulnerability and risk maps; publicly accessible data portal.
# - FPIC framework finalized and first rounds of district consultations completed.
# - 2–4 pilot nature-based defense projects operational; performance reports.
# - Early warning and communications upgrade plan completed.
#
# Phase B: Phase 2–Phase 3 (Year 3–Year 6)
# Objectives: Scale up protection where feasible; begin more extensive managed retreat pilots; expand economic resilience and social nets; protect cultural heritage where possible.
# Actions and responsibilities
# - Expand coastal defenses (hybrid approaches: hard defences in high-value zones; nature-based measures in buffer zones; improve drainage and flood-proofing).
#   - Responsible: Coast Protection Authority; Ministry of Infrastructure; Local Governments; Community partners.
# - Implement managed retreat pilots in selected neighbourhoods with clear risk gradients and strong community consent; acquire land or easements where feasible; fund relocation to inland zones with basic services.
#   - Responsible: MUDH; MEC; NDMA; Local Governments; Finance Authority.
# - Inland relocation planning: design and construct inland resettlement sites with utilities, schools, clinics, markets; ensure access to livelihoods (e.g., aquaculture supply chain hubs relocated inland, business incubation).
#   - Responsible: MUDH; Ministry of Culture (heritage integration); Fisheries and Maritime Affairs (livelihood continuity).
# - Economic resilience programs: diversify livelihoods (alternative energy, tourism diversification away from high-risk coastlines, fisheries diversification, cold-chain logistics); microfinance and insurance expansion for coastal workers.
#   - Responsible: Ministry of Economic Affairs; Fisheries and Maritime Affairs; Ministry of Culture; Local Governments.
# - Social safety nets: broaden unemployment benefits, health access, housing assistance during relocation, transitional income supports.
#   - Responsible: Ministry of Social Welfare; Health Ministry; MOF (fiscal authority).
# - Cultural heritage: digital documentation and commemoration of heritage sites; where relocation occurs, plan for on-site archival or relocation of movable heritage; engage communities in protecting intangible heritage (song, language, traditional practices).
#   - Responsible: Ministry of Culture; Indigenous and Cultural Affairs Office; Local Cultural Councils.
# - Monitoring and governance: quarterly risk reviews; public dashboards; annual independent audit on equity outcomes and consent processes.
# - Budget: 3% of GDP; approximate allocation: Coastal Defenses 40–50%, Managed Retreat/Relocation 20–25%, Economic Resilience 15–20%, Social Safety Nets 8–12%, Cultural Heritage 5–7%.
#
# Deliverables
# - Expanded defenses in high-risk zones; retreat pilot communities relocated or legally empowered to move.
# - Inland settlement master plans with infrastructure and livelihood linkages.
# - Livelihood diversification programs scaled; insurance schemes accessible to coastal workers.
# - Digitized cultural heritage records; public-facing heritage archive; community memory initiatives.
#
# Phase C: Phase 4–Phase 5 (Year 7–Year 10)
# Objectives: Consolidate protective measures, scale up relocation where consented and feasible, deepen resilience and economic adaptation, and integrate heritage protection with living communities.
# Actions and responsibilities
# - Scale-up “relocation-forward” where communities express clear consent and risk indicates unsustainable in-situ protection; invest in inland infrastructure and service hubs including healthcare, education, and markets.
# - Harden critical infrastructure (roads, ports, power, water) to support adaptation outcomes; continue integrated water management and flood control; expand natural buffers (reforestation of mangroves, barrier reefs where ecologically appropriate).
# - Strengthen seafood value chains and climate-smart fisheries; promote sustainable tourism that is not exposed to the same coastal hazards (e.g., ecotourism inland or in safer coastal belts).
# - Expand financial mechanisms: resilient investment funds, indexed catastrophe bonds if feasible, micro-insurance for households, floodplain land-use transfer programs with clear titling.
# - Cultural heritage adaptation: maintain on-site protection where feasible; relocate critical artifacts and create living museums where relocation is necessary; ensure language and traditional practices are embedded in inland communities.
# - Equity and governance: ongoing FPIC updates; grievance mechanisms; public reporting and citizen oversight.
# - Budget: 3% of GDP; approximate allocation: Coastal Defenses 25–40%, Managed Retreat/Relocation 25–30%, Economic Resilience 20–25%, Social Safety Nets 8–12%, Cultural Heritage 5–7%.
#
# Deliverables
# - Large-scale protective infrastructure where cost-effective; relocation programs with completed land acquisition or relocation plans; inland service hubs functioning with livelihoods integrated.
# - Strengthened value chains for coastal communities; diversified tourism assets; continuing cultural heritage safeguards.
#
# Phase D: Phase 6–Phase 7 (Year 11–Year 13)
# Objectives: Shift toward long-term resilience, adapt to evolving risk, and ensure sustainable living conditions for relocated and in-place communities; prepare for policy sunset or transition.
# Actions
# - Finalize protection and relocation balance across districts with robust public consent documentation; complete sectoral resilience programs; scale back noncritical investments if risk reduced or budget constrained.
# - Maintain surveillance of coastline changes; adapt defenses to cost-effective upgrades; maintain natural buffers to maximize benefits for ecosystem services.
# - Continue funding for social safety nets and ensure equitable access to opportunities in inland areas (education, healthcare, jobs).
# - Heritage programs: consolidate digital stores, maintain local memory centers, formal recognition of community heritage events, and ensure tourism pipelines support heritage preservation.
# - Budget: 3% of GDP with allocation band tightening as necessary; typical shares: Coastal Defenses 20–35%, Managed Retreat/Relocation 25–35%, Economic Resilience 20–25%, Social Safety Nets 8–12%, Cultural Heritage 5–8%.
#
# Deliverables
# - Sustainable balance of defense and retreat; functioning inland communities with preserved livelihoods; ongoing cultural heritage preservation.
#
# Phase E: Phase 8–Phase 9 (Year 14–Year 15)
# Objectives: Evaluation, adaptation, and policy refinement; plan for steady-state governance of coastline resilience, with clear sunset/transition criteria for future budgets and authorities.
# Actions
# - Final policy evaluation; publish comprehensive 15-year report; update risk maps and land-use plans; set next horizon commitments if needed.
# - Institutionalize ongoing citizen oversight and FPIC processes for any future expansions or reconfigurations.
# - Maintain and improve inland livelihoods; ensure equitable outcomes across communities; finalize cultural heritage integration into inland life.
# - Budget: 3% of GDP but with explicit sunset clauses or transition plans, reflecting the long-term viability and projected risk.
#
# Deliverables
# - Publicly accessible 15-year evaluation and a plan for ongoing adaptation beyond Year 15.
#
# 4) Concrete decision framework for protecting in place vs retreat vs relocation (how to make choices, what inputs are used, and how values are included)
# - Core decision criteria (scored for each district/area using a consistent rubric; 0–5 scale for each criterion; total 0–25 or normalized 0–100):
#   - Hazard exposure: current and projected rate of sea‑level rise, storm surge, erosion, flood depth, salinity intrusion.
#   - Vulnerability: population density, reliance on coastal livelihoods, presence of vulnerable groups, displacement risk.
#   - Asset exposure: value of built infrastructure, healthcare, schools, critical facilities, cultural sites; replacement costs.
#   - Cost of protection: estimated cost of defenses to bring risk to an acceptable level; maintenance costs.
#   - Feasibility: engineering feasibility, land availability for retreat/relocation, governance readiness, local support.
#   - Cultural significance: presence and importance of cultural sites, language and heritage, nonmarket values (identity, memorial values).
#   - Equity/Consent: presence of FPIC or consent from affected communities; potential impact on marginalized groups.
#   - Economic impact: effect on livelihoods (fisheries, tourism, transport); potential for alternative livelihoods.
# - Valuation of nonmarket losses and cultural sites:
#   - Cultural significance scores (qualitative input from Indigenous and community stakeholders) combined with contingent valuation surveys and willingness-to-pay measures for preservation of heritage and cultural memory.
#   - Nonmarket ecosystem services: mangrove buffers, coastal protection, nutrient cycling, biodiversity; monetized via ecosystem-services valuation where possible.
#   - Indirect costs and benefits: social cohesion, mental health, community resilience, and intergenerational equity.
# - Decision rules (summary):
#   - Protect in place if hazard exposure is moderate, economic/strategic assets are high-value, feasibility is high, and cultural sites have strong ties to identity; with consent from affected communities.
#   - Retreat if exposure is high-to-severe, protection costs exceed threshold (set ex ante), land for protections is insufficient or untenable, community consent supports relocation, and alternative livelihoods exist.
#   - Relocate if critical infrastructure or large population centers face high risk, cost of protection is prohibitive, and feasible inland sites with services exist; cultural heritage can be preserved via digitization and on-site relocation where possible.
#
# 5) Budget allocation and financing mechanics
# - Annual envelope: 3% of current GDP.
# - Proposed indicative allocation bands (as percent of GDP per year, to be refined when GDP is known):
#   - Coastal defenses and nature-based defense projects: 35–45%
#   - Managed retreat and relocation costs (acquisition, housing, inland service hubs, compensation): 15–25%
#   - Economic resilience programs (livelihood diversification, fisheries adaptation, climate-smart tourism, value chains): 15–25%
#   - Social safety nets and transition supports: 8–12%
#   - Cultural heritage preservation and adaptation: 5–10%
# - Example (illustrative numbers for a $20B GDP baseline; totals 3% ≈ $600M):
#   - Coastal defenses: $210–$270M (35–45%)
#   - Managed retreat/relocation: $90–$150M (15–25%)
#   - Economic resilience: $90–$150M (15–25%)
#   - Social safety nets: $48–$72M (8–12%)
#   - Cultural heritage: $30–$60M (5–10%)
# - Revenue and finance considerations:
#   - Use a mix of annual appropriations, contingent reserves, and legitimate debt instruments for capital-intensive defenses, with clear debt service costs and sunset/return-to-revenue plans.
#   - Explore blended finance: national funds, climate finance facilities, concessional loans, international grants, and public-private partnerships for selective infrastructure and relocation projects.
#   - Ensure fiscal efficiency with competitive procurement, performance-based contracts, and independent audits.
# - Contingency and scaling:
#   - If GDP growth slows, maintain minimum essential protections for high-risk districts; scale back noncritical activities; retain FPIC and equity commitments.
#   - If political support wanes, lock in core protections and safety nets through legal frameworks and transparent public reporting; emphasize citizen oversight.
#
# 6) Measurable metrics, monitoring protocols, and explicit contingency triggers
# - Metrics (annual and phase-based):
#   - Area protected in place (km2) and population protected; number of communities opting to relocate; number of households supported by relocation or insurance; share of critical infrastructure hardened or relocated; number of cultural sites preserved or digitized; employment diversification metrics; poverty rate changes in coastal regions; health access indicators in inland hubs; public satisfaction and consent rates.
#   - Ecosystem services indicators: coastal buffer integrity, mangrove extent, sediment stability, biodiversity indices.
#   - Financial metrics: annual expenditures by category; cost per person protected or relocated; return on investment for livelihood programs.
#   - Governance metrics: FPIC approvals completed; public dashboards updated; number of independent audits; grievance resolution times.
# - Monitoring protocols:
#   - Independent Coastal Outcomes Commission (ICOC) conducts annual audits of program performance, equity outcomes, and consent processes; publishes a comprehensive public report with data access.
#   - Regular hazard monitoring using national sensors, satellite remote sensing, and ground truthing; quarterly risk-reassessment reports; biannual updates to risk maps.
#   - Community-based monitoring with local councils: monthly reports on local conditions, feedback, and concerns; participatory budgeting updates in each district.
#   - Cultural heritage monitoring: independent heritage assessors assess digitization progress, on-site protection status, and community satisfaction with preservation efforts.
# - Contingency triggers that would require strategy shifts (examples):
#   - Trigger A: Hazard exposure or land loss accelerates beyond modeled scenarios (e.g., actual erosion rates exceed the mid-range model by more than 50% for two consecutive years). Action: pause noncritical relocations, accelerate high-value protections in the worst zones, revisit cost-benefit analysis, and potentially reallocate funds to immediate protections.
#   - Trigger B: Budget under-execution or a funding gap >40% of planned annual appropriation. Action: implement a formal scaled-back plan prioritizing high-risk, high-value protections and safety nets; activate contingency financing plans; pause low-priority projects.
#   - Trigger C: Consent failures or significant opposition to relocation in multiple districts; repeated FPIC revocation or protests with clear risks to social stability. Action: re-engage communities with emphasis on benefit sharing, revise compensation, adjust land-use plans, and potentially defer relocations.
#   - Trigger D: Infrastructure failures or severe disaster events indicating unanticipated risk magnitude (e.g., unprecedented storm surge). Action: immediate protective escalations, emergency funding, and rapid design revisions.
#   - Trigger E: Major macroeconomic shock (double-digit recession sustained for 4 quarters). Action: prioritize safety nets and critical services; defer nonessential capital investments; pursue international climate finance where possible.
#   - Trigger F: Inability to protect or relocate certain communities due to land rights complexities or legal obstacles. Action: implement alternative living arrangements, compensation, or cultural preservation by digitization and memory work, while continuing to pursue resolution.
# - Evaluation of success over time:
#   - Annual public reporting against a core dashboard of coverage (area protected, people protected, number of relocations completed, livelihood outcomes), equity metrics (consent rates, benefits for vulnerable groups), and cultural heritage outcomes (sites preserved/digitized).
#   - Mid-term independent review at Year 7 with a revised plan if necessary (reevaluate risk, costs, consent, and equity outcomes).
#   - Final Year 15 evaluation against baseline and target metrics; publish lessons learned and a recommended long-term governance structure for ongoing coastal resilience with explicit sunset/start-up of a new cycle if needed.
#
# 7) Meaningful inclusion and equity in decision-making (how vulnerable and Indigenous communities are included, and how equity is ensured)
# - FPIC throughout: any decision affecting Indigenous communities or areas with high Indigenous significance requires Free, Prior, Informed Consent; community decisions influence options and cost-sharing structures; consent is revisited if risk or circumstances change materially.
# - Governance inclusion:
#   - Seats for Indigenous representatives and vulnerable community leaders in the ICC and CEOC; district-level community advisory councils with gender and disability representation; youth and fisherfolk representation embedded in decisions affecting livelihoods.
#   - Language access, accessible meetings, and culturally appropriate processes; capacity-building funds to help communities understand trade-offs, costs, and compensation schemes.
# - Equity safeguards:
#   - Equity impact assessments for all major decisions; targeted support for the most vulnerable (low-income households, women, elderly, people with disabilities) during relocation or transition.
#   - Guaranteed livelihood options in inland settlements (jobs, schooling, healthcare, market access) and consistent access to social safety nets for at least a defined transition period.
#   - Transparent grievance mechanisms with independent mediation and appeal processes; clear compensation standards for land acquisitions and livelihood losses.
# - Cultural heritage and Indigenous rights:
#   - Prioritization of preservation and respectful relocation options for heritage and cultural sites; digital archiving and community-led interpretation of heritage; involvement of community guardians in protecting intangible cultural heritage (language, songs, ritual practices).
#
# 8) Ethical justification of trade-offs, key assumptions, risks, and an alternate contingency plan
# - Ethical justification:
#   - Protecting lives, livelihoods, and basic rights in the face of climate risk is a legitimate state obligation in a democracy; actions are designed to minimize coercive displacement, maximize community consent, and provide fair compensation and alternative livelihoods.
#   - The plan prioritizes least-disruption approaches consistent with consent (protect in place where feasible, retreat only where necessary, and relocate with meaningful community input and support). It also prioritizes cultural heritage preservation, memory, and identity as essential components of a just transition.
# - Key quantitative assumptions (explicit):
#   - SLR and hazard projections are based on mid-range IPCC-style scenarios with sensitivity analyses.
#   - 20% of coastal land area is at risk over 40 years; distributions by district follow current exposure patterns; defense costs are within ranges for hybrid nature-based and structural defenses; relocation costs reflect land acquisition, housing, and inland service development.
#   - 3% GDP annual budget envelope with adjustments for inflation; finance costs and debt service considered where capital investments are debt-funded; government will maintain social safety nets to protect vulnerable groups.
#   - Nonmarket losses and cultural values can be quantified via a combination of contingent valuation and ecosystem-service valuation methods, with strong community input to weight cultural factors.
# - Main risks and unintended consequences:
#   - Inequitable outcomes if consent is unevenly achieved, or if relocation creates new forms of marginalization (e.g., in-migration to inland districts overwhelming services).
#   - Economic risks if defense investments fail to deliver expected protection or if relocation disrupts livelihoods without viable alternatives; potential for “double exposure” where defenses induce growth in risky areas.
#   - Environmental risks if hard defenses cause erosion of other areas, degrade natural buffers, or alter sediment transport; ecosystem disruption could occur if nature-based solutions are not properly designed.
#   - Governance and political risks: public trust could erode if costs, benefits, or consent processes appear opaque; delays in land acquisition or permitting could derail timelines.
# - Alternate contingency plan for a 40% funding cut or reduced political support:
#   - Prioritize core safety-net guarantees and high-risk protections; defer nonessential resilience investments; accelerate innovations that deliver high leverage with lower costs (e.g., targeted nature-based approaches, community-led defenses, and low-cost monitoring).
#   - Scale-back relocation by focusing first on districts where risk is highest and consent is strongest; adopt incremental, low-cost relocation options (e.g., shared facilities, phased transitions, and mixed-use inland hubs).
#   - Seek alternative financing: climate finance facilities, international grants, concessional loans, and public-private partnerships for selected high-impact projects with clear risk-sharing and performance metrics.
#   - Strengthen governance and transparency: maintain public dashboards, publish rapid-assessment reports, and maintain a citizen oversight body to sustain legitimacy during constrained periods.
#   - Reassess risk, re-prioritize allocations, and publish an updated, publicly justified plan with revised timelines and targets.
#
# 9) How success would be evaluated and how to adapt over time
# - Short-term (Year 1–Year 3): Baseline risk maps completed; FPIC processes underway; pilot defenses and relocation pilots initiated; dashboards and reporting system operational; pillars of social safety nets established.
# - Medium-term (Year 4–Year 6): Expansion of defenses in high-risk zones; relocation pilots progressing; inland service hubs functional; diversified livelihoods in place; heritage digitization completed for key sites; governance and consent processes institutionalized.
# - Long-term (Year 7–Year 15): Consolidated protective and relocation framework; resilient livelihoods across inland zones; cultural heritage preserved and integrated; risk monitoring and governance sustainability assured; plan for ongoing adaptation beyond Year 15.
# - Success indicators:
#   - Reduced annual exposure and number of people at risk; proportion of critical infrastructure protected or relocated; stable or improving livelihoods in coastal and inland communities; strong indicators of equity (consent rates, participation, and benefits for vulnerable groups); heritage preservation outcomes; public trust and transparent governance metrics.
# - Transparent reporting:
#   - Annual “State of the Coast” report with public dashboards; independent reviews at mid-term and end-term; open data in machine-readable formats to enable external analysis and public scrutiny.
#
# 10) Summary of deliverables and responsibilities by sector
# - Governance and inclusion
#   - ICC, CEOC, FPIC processes, district community councils; public dashboards; independent audits.
# - Engineering and protection
#   - Coastal Protection Authority; Ministry of Infrastructure; local governments; nature-based solution pilots; critical infrastructure upgrades.
# - Relocation and settlements
#   - Ministry of Urban Development and Housing; land acquisition and resettlement planning; inland service hubs; livelihood linkages.
# - Economic resilience and livelihoods
#   - Ministry of Economic Affairs; Fisheries and Maritime Affairs; tourism diversification; insurance and microfinance programs.
# - Social safety nets
#   - Ministry of Social Welfare; health services; affordable housing in inland hubs; social protection programs.
# - Cultural heritage and Indigenous rights
#   - Ministry of Culture; Indigenous and Cultural Affairs Office; heritage digitization; commemorative and memory initiatives; FPIC oversight.
# - Monitoring and accountability
#   - ICOC; National Statistics Office; NDMA; independent auditors; public reporting.
#
# If you would like, I can convert this into a concrete year-by-year action plan with explicit budget lines (in local currency and in terms of GDP percentages), a scoring rubric template for the protection/retreat/relocation decision, and a set of sample dashboards and data requests to share publicly. I can also adapt the plan to a hypothetical GDP figure (e.g., $20B vs. $30B) to illustrate annual budget magnitudes and project costs in more precise terms.
# Competitor: gemini-2.5-flash
#
# As Chief Advisor, I present this 15-year plan for our coastal nation of 4 million people, facing the existential threat of losing 20% of its land area to sea-level rise (SLR) within 40 years. This plan is designed to be publicly justifiable, protect democratic inclusion, and leverage our annual budget of 3% of current GDP (approx. $4.8 billion per year).
#
# ---
#
# ### **A Resilient Future: A 15-Year National Adaptation Plan for Sea-Level Rise**
#
# **Core Vision:** To transform our nation into a global leader in climate adaptation, safeguarding our people, culture, and economy through strategic protection, managed retreat, and innovative resilience, ensuring a just and equitable transition for all.
#
# **Guiding Principles:**
# 1.  **People First:** Prioritizing the safety, well-being, and dignity of our citizens.
# 2.  **Justice & Equity:** Fair distribution of burdens and benefits, especially for vulnerable and Indigenous communities.
# 3.  **Transparency & Accountability:** Open decision-making, data-driven policies, and continuous public engagement.
# 4.  **Economic Reinvention:** Building a vibrant, climate-resilient economy that fosters new opportunities.
# 5.  **Cultural Stewardship:** Preserving our unique heritage, both tangible and intangible.
# 6.  **Adaptive Governance:** Flexibility to adjust strategies based on evolving science and on-the-ground realities.
#
# **Contextual Assumptions:**
# *   **Population:** 4 million
# *   **Assumed Current GDP:** $160 Billion (approx. $40,000 per capita)
# *   **Annual Budget Allocation:** 3% of GDP = **$4.8 Billion/year**
# *   **Total 15-Year Budget:** **$72 Billion**
# *   **Sea Level Rise Projection:** High-end scenario, implying an aggressive rate of inundation and erosion, leading to 20% land loss in 40 years.
# *   **Political Will:** Strong initial national consensus and sustained political commitment.
#
# ---
#
# ### **Part 1: Prioritized, Phased 15-Year Plan**
#
# The plan is divided into three 5-year phases, each building upon the previous, with continuous monitoring and adaptation.
#
# **Phase 1: Foundation, Assessment & Pilot Implementation (Years 1-5)**
# *   **Goal:** Establish legal, institutional, and data foundations; foster public understanding and engagement; conduct detailed assessments; initiate pilot projects.
# *   **Annual Budget Allocation:** $4.8 Billion
#
# | Action Area                        | Concrete Actions                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Responsible Agencies                                                                                                                    | Timeline    |
# | :--------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :-------------------------------------------------------------------------------------------------------------------------------------- | :---------- |
# | **1.1 Governance & Legal Framework** | - Establish a **National Coastal Adaptation Authority (NCAA)** as the central coordinating body. <br> - Enact a comprehensive **Coastal Adaptation Act (CAA)**, defining mandates for adaptation, land use, compensation, and eminent domain for retreat. <br> - Amend zoning regulations for "no-build" and "retreat-ready" designations in at-risk areas.                                                                                                            | Ministry of Justice, Ministry of Environment, NCAA (once established), Parliament                                                     | Y1-Y2       |
# | **1.2 Data & Risk Assessment**     | - Conduct high-resolution LiDAR mapping, bathymetric surveys, and dynamic SLR modeling for the entire coastline (priority on high-risk zones). <br> - Map all critical infrastructure, cultural sites, and population density within projected inundation zones. <br> - Establish a national multi-hazard early warning system.                                                                                                                                     | Ministry of Environment, National Geographic Institute, Meteorological Agency, NCAA                                                     | Y1-Y3       |
# | **1.3 Public Engagement & Awareness**| - Launch "Our Shifting Shores" public education campaign (media, schools, community workshops). <br> - Establish **Regional Adaptation Councils (RACs)** with diverse community and Indigenous representation. <br> - Create an interactive online portal for data, planning, and feedback.                                                                                                                                                                           | Ministry of Information, Ministry of Education, NCAA, Local Governments                                                                 | Ongoing (Y1-Y15) |
# | **1.4 Economic & Social Resilience**| - Assess national economic vulnerability to SLR (fisheries, tourism, agriculture, ports). <br> - Initiate pilot skills training programs for emerging green and blue economy sectors. <br> - Develop a national digital infrastructure blueprint to support economic decentralization.                                                                                                                                                                             | Ministry of Economy, Ministry of Labor, NCAA                                                                                            | Y2-Y5       |
# | **1.5 Pilot Projects**             | - Implement 2-3 "Protect in Place" pilot projects (e.g., mangrove restoration, small-scale dykes) in diverse communities. <br> - Execute 1-2 small-scale "Managed Retreat/Relocation" pilot projects, emphasizing voluntary participation, comprehensive compensation, and social support. <br> - Document lessons learned and best practices.                                                                                                                             | NCAA, Ministry of Infrastructure, Local Governments, Community Groups                                                                   | Y3-Y5       |
# | **1.6 Cultural Heritage Mapping**  | - Comprehensive mapping, documentation, and vulnerability assessment of all tangible and intangible cultural sites in threatened zones, in partnership with Indigenous communities. <br> - Develop emergency salvage and preservation protocols.                                                                                                                                                                                                                             | Ministry of Culture, Indigenous Affairs Department, NCAA                                                                                | Y1-Y3       |
#
# **Phase 2: Scaling Up & Major Infrastructure (Years 6-10)**
# *   **Goal:** Implement large-scale adaptation projects; accelerate managed retreat and relocation; bolster economic resilience and social safety nets.
# *   **Annual Budget Allocation:** $4.8 Billion
#
# | Action Area                        | Concrete Actions                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Responsible Agencies                                                                                                                    | Timeline    |
# | :--------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :-------------------------------------------------------------------------------------------------------------------------------------- | :---------- |
# | **2.1 Coastal Defenses (Protect)** | - Begin construction of priority hard defenses (sea walls, surge barriers) for critical economic hubs, major cities, and identified "protect-in-place" communities. <br> - Scale up nature-based solutions (mangrove restoration, coral reefs, dune systems) in suitable areas. <br> - Implement strategic beach nourishment programs.                                                                                                                                      | Ministry of Infrastructure, NCAA, Ministry of Environment                                                                               | Y6-Y10      |
# | **2.2 Managed Retreat & Relocation**| - Initiate the first wave of large-scale, voluntary managed retreat and strategic relocation for identified communities. <br> - Develop "Receiving Communities" with necessary infrastructure and services in designated upland areas. <br> - Establish a national land bank for future relocation and ecosystem restoration. <br> - Provide comprehensive financial, housing, and social support for relocating families and businesses.                                      | NCAA, Ministry of Housing, Ministry of Social Welfare, Local Governments, Land Affairs Agency                                         | Y6-Y10      |
# | **2.3 Economic Transformation**    | - Establish Special Economic Zones (SEZs) in inland areas focused on climate-resilient industries (e.g., advanced manufacturing, agri-tech, renewable energy, sustainable aquaculture). <br> - Provide grants and low-interest loans for businesses to relocate or transition to resilient sectors. <br> - Invest in R&D for climate adaptation technologies.                                                                                                                     | Ministry of Economy, NCAA, National Innovation Agency                                                                                   | Y6-Y10      |
# | **2.4 Social Safety Nets**         | - Expand national social safety nets to cover climate-induced displacement and income loss (e.g., unemployment, housing assistance). <br> - Establish mental health and psychosocial support services for affected communities. <br> - Develop robust educational integration programs for relocated children.                                                                                                                                                             | Ministry of Social Welfare, Ministry of Health, Ministry of Education, NCAA                                                             | Y6-Y10      |
# | **2.5 Cultural Heritage Protection**| - Begin strategic relocation/salvage of highly vulnerable tangible cultural artifacts and archives. <br> - Implement advanced digital preservation of intangible heritage (oral histories, traditions) with community involvement. <br> - Co-design preservation strategies for sacred sites with Indigenous communities.                                                                                                                                              | Ministry of Culture, Indigenous Affairs Department, NCAA, National Archives                                                             | Y6-Y10      |
#
# **Phase 3: Full-Scale Adaptation & Long-Term Transition (Years 11-15)**
# *   **Goal:** Consolidate adaptation efforts, ensure long-term sustainability, and continuously monitor and adjust strategies for enduring resilience.
# *   **Annual Budget Allocation:** $4.8 Billion
#
# | Action Area                        | Concrete Actions                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Responsible Agencies                                                                                                                    | Timeline    |
# | :--------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :---------- |
# | **3.1 Integrated Coastal Management**| - Fully operationalize the NCAA as the primary coordinating body for all adaptation efforts. <br> - Implement adaptive management protocols for all coastal defenses, ensuring maintenance and upgrades based on evolving SLR projections. <br> - Establish a permanent national fund for long-term coastal resilience and emergency response.                                                                                                                             | NCAA, Ministry of Finance                                                                                                               | Y11-Y15     |
# | **3.2 Sustained Retreat & Relocation**| - Continue large-scale managed retreat and strategic relocation, integrating lessons learned from previous phases. <br> - Focus on land-use planning in receiving areas to prevent future displacement. <br> - Conduct post-relocation impact assessments to ensure successful integration and well-being of relocated communities.                                                                                                                                         | NCAA, Ministry of Housing, Local Governments                                                                                            | Y11-Y15     |
# | **3.3 Resilient Economy & Infrastructure**| - Support the full transition of the national economy towards climate-resilient and sustainable sectors. <br> - Invest in resilient infrastructure (e.g., climate-proofed transportation, decentralized energy grids, water systems). <br> - Promote blue/green economy initiatives in newly restored coastal ecosystems.                                                                                                                                             | Ministry of Economy, Ministry of Infrastructure, NCAA                                                                                   | Y11-Y15     |
# | **3.4 Enhanced Social Cohesion**   | - Implement programs to foster social cohesion between original residents and relocated communities. <br> - Develop specific support for elderly, disabled, and other vulnerable groups in the transition process. <br> - Establish permanent, independent grievance mechanisms for adaptation-related issues.                                                                                                                                                              | Ministry of Social Welfare, Local Governments, NCAA                                                                                     | Y11-Y15     |
# | **3.5 Legacy & Future Planning**   | - Establish national memorials and digital archives for lost landscapes and heritage. <br> - Develop a long-term (50-100 year) national vision for a post-SLR resilient nation, including land use and demographic projections. <br> - Continuously update scientific projections and adaptation strategies based on global best practices and local monitoring.                                                                                                              | NCAA, Ministry of Culture, National Planning Commission                                                                                 | Y11-Y15     |
#
# ---
#
# ### **Part 2: Objective Criteria and Transparent Decision Framework**
#
# Decisions to protect, retreat, or relocate are profound. Our framework employs a multi-criteria analysis (MCA) with expert assessment and extensive community consultation, overseen by the NCAA. The weighting of criteria will be finalized through public dialogue.
#
# **Decision Categories:**
# 1.  **Protect in Place (High-Value Retention):** Maintain current location with significant coastal defenses.
# 2.  **Managed Retreat (Strategic Relocation):** Phased, planned movement of communities and infrastructure from vulnerable areas.
# ...
#
# **Alternate Contingency Plan (40% Funding Cut or Reduced Political Support):**
#
# If annual funding falls by **40%** (to $2.88 Billion) or political support significantly diminishes, the plan must pivot to a survival-focused approach.
#
# *   **Re-prioritization Logic:** Shift from "optimize for long-term resilience and equity" to "minimize immediate human suffering and safeguard critical national functions."
# *   **Strategic Adjustments:**
#     *   **Coastal Defenses:** Limit to absolutely essential infrastructure protecting national strategic assets (capital city, primary port, power generation). Halt new large-scale hard defense projects. Prioritize cost-effective nature-based solutions.
#     *   **Managed Retreat & Relocation:** Prioritize only communities in imminent danger or those with the highest vulnerability/lowest relocation cost. Voluntary aspects would be curtailed, shifting towards more directive, though compensated, processes.
#     *   **Minimalist Relocation Support:** Compensation would shift from "fair market value + premium" to "fair market value only" or basic housing and livelihood support. Social safety nets would focus on emergency aid.
#     *   **Economic Programs:** Focus on essential retraining for displaced populations. Halt grants for new climate-resilient industries.
#     *   **Cultural Heritage:** Focus solely on digital documentation and emergency salvage of irreplaceable items. Long-term preservation deferred.
#     *   **Leaner Governance:** Significant reduction in NCAA staffing and outreach, focusing on core coordination and emergency response.
# *   **Ethical Implications:** This contingency would necessitate starker trade-offs, prioritizing survival and minimizing harm over optimal well-being and comprehensive equity. It acknowledges that not everyone can be helped equally when resources are severely constrained, shifting towards a **Triage** ethical framework.
# *   **Evaluation of Success in Contingency:** Success would be redefined as minimizing loss of life, maintaining basic governance, preventing widespread social collapse, and protecting core national assets. Metrics would focus on humanitarian aid delivery, lives saved, and maintenance of essential services.
#
# **How to Evaluate Success Over Time:**
#
# Evaluation is continuous, iterative, and adaptive across all phases:
#
# *   **Short-Term (Years 1-5):** Success is judged by establishing foundational elements: legal frameworks enacted, NCAA operational, high-res mapping completed (e.g., 90% coverage), public awareness increased (e.g., 70% understanding), pilot projects initiated, and community feedback integrated.
#     *   **Evaluation:** Annual NCAA reports, parliamentary oversight, public satisfaction surveys on information dissemination.
# *   **Mid-Term (Years 6-10):** Success is judged by scaling up implementation and showing initial impact: X communities protected/relocated, Y hectares defended, Z jobs created, Q% reduction in displacement-related poverty, cultural sites digitally documented.
#     *   **Evaluation:** Biennial independent audits, scientific review panels, community outcome surveys (relocation satisfaction, access to services), economic impact assessments.
# *   **Long-Term (Years 11-15 & Beyond):** Success is judged by achieving sustainable resilience and a transformed nation: overall reduction in vulnerability (e.g., 50% less population at high risk than baseline), sustained economic growth in climate-resilient sectors, high social cohesion in new communities, all critical cultural heritage protected or documented, and enhanced national capacity to adapt to future SLR.
#     *   **Evaluation:** Comprehensive 15-year plan review against original objectives, independent socio-economic and environmental impact studies, comparison with international best practices, long-term well-being indicators, and intergenerational equity assessments.
#
# This adaptive approach ensures that our nation remains agile and effective in confronting the ongoing challenge of sea-level rise, building a resilient and equitable future for all.
# Competitor: gemma3:1b-it-qat
#
# Okay, here’s a detailed, phased 15-year plan designed to address the projected loss of land area due to sea-level rise in a 4 million population coastal nation, prioritizing democratic inclusion, public justification, and long-term resilience. This plan acknowledges the complexity, the need for adaptation, and leverages a cautious, proactive approach.
#
# **I. Executive Summary:**
#
# This plan acknowledges the escalating threat of sea-level rise and aims to mitigate its worst effects through a multi-pronged approach prioritizing community protection, economic stability, cultural preservation, and social equity.  The $3% of GDP annual budget is a realistic constraint, requiring careful prioritization and strategic allocation.  Transparency and public justification are fundamental.  Success is measured through a combination of quantifiable metrics, rigorous monitoring, and flexible contingency plans.
#
# **II. Prioritized Phased Plan (15 Years)**
#
# **Phase 1: Assessment & Initial Response (Years 1-3) – $1.5 Billion (Approx. 20% - Adjust Based on Initial Data)**
#
# *   **Goal:** Establish a baseline understanding, initiate immediate protective measures, and build initial community trust.
# *   **Actions:**
#     *   **Coastal Mapping & Vulnerability Assessment (Q1-Q3):**  Deploy drones and GIS specialists to create detailed maps of vulnerable coastal areas, identifying specific risks (e.g., erosion patterns, high-risk zones). Conduct detailed socio-economic assessments of affected communities.
#     *   **Emergency Resilience Infrastructure (Q2-Q4):**  Establish regional, localized flood defenses (levees, seawalls – prioritizing strategic placement to minimize negative impacts on farmland and critical infrastructure).  Create early warning systems.
#     *   **Community Engagement & Education (Q1-Q3):**  Launch town hall meetings, online forums, and public awareness campaigns promoting climate adaptation and relocation strategies.  Focus on communicating the potential impacts clearly and empathetically.
#     *   **Initial Retreat Planning (Q3-Q4):**  Form a stakeholder panel consisting of representatives from local governments, communities, environmental experts, and economists to establish the initial scale of retreat zones and develop specific relocation strategies.
# *   **Objective Criteria:**  Documented vulnerability assessments; initial flood defense infrastructure presence; baseline understanding of community priorities; community engagement levels.
# *   **Decision Framework:**  Weighted scoring based on risk assessment, social impact, economic necessity, and community consensus.  Transparency in assessment methodology.
# *   **Budget Allocation:**  $600 Million – Emergency response, mapping, initial defenses, education, and relocation planning.
#
# **Phase 2:  Strategic Retreat & Economic Transition (Years 4-7) – $3 Billion (Approx. 40% - Adjust Based on Retreat Impact)**
#
# *   **Goal:**  Reduce vulnerability through targeted retreat, facilitate economic diversification, and address social impacts.
# *   **Actions:**
#     *   **Targeted Retreat Implementation (Q1-Q4):**  Implement relocation plans for the most vulnerable populations based on the previous phase’s findings and updated projections. Prioritize communities with higher concentrations of vulnerable populations and critical infrastructure.  Focus on creating “smart” retreats – resilient but adaptable communities.
#     *   **Economic Diversification Support (Q1-Q4):**  Provide grants and tax incentives to businesses that relocate or adopt new industries.  Offer vocational training programs to support this transition. Focus on sustainable tourism, aquaculture, and new green technologies.
#     *   **Land Use Planning Updates (Q2-Q4):**  Re-evaluate land use regulations – moving away from continuous coastal development towards zones with higher natural vegetation cover and protection.
#     *   **Social Safety Net Enhancement (Q2-Q4):**  Strengthen social safety net programs (food assistance, housing assistance, healthcare) to support those displaced or struggling to adapt.  Ensure culturally appropriate support systems.
# *   **Objective Criteria:**  Reduced population density in retreat zones; demonstrable economic growth within relocated areas; progress towards social safety net adequacy.
# *   **Decision Framework:**  Focus on “just” – equitable distribution of resources across affected communities. Transparency linked to equitable restoration and cultural preservation.  Regular feedback and review from impacted groups.
# *   **Budget Allocation:** $1.75 Billion – Relocation assistance, economic transition funds, support services, environmental restoration.
#
# **Phase 3: Adaptive Resilience & Long-Term Planning (Years 8-12) – $1.2 Billion (Approx. 30% - Adjusted based on retreat impacts)**
#
# *   **Goal:** Optimize adaptation strategies, implement long-term infrastructure, and deepen community engagement.
# *   **Actions:**
#     *   **Adaptation Infrastructure – Smart Coastal Barriers (Q1-Q4):** Focus on adaptive sea defenses (drones, modular flood barriers) that can be adjusted and maintained based on data.
#     *   **Climate-Resilient Agriculture (Q1-Q4):** Invest in supporting local, sustainable agricultural practices – aquaculture, seaweed farming, micro-nutrient agriculture – to build economic resilience.
#     *    **Cultural Heritage Protection (Q2-Q4):** Establish a dedicated safeguarding fund, collaborate with local experts to catalog and document heritage sites.
#     *    **Community Consultation (Ongoing):** Implement regular, transparent community consultations on all long-term adaptation plans.
# *   **Objective Criteria:**   Reduced risk of climate impacts; successful implementation of adaptation plans; sustained community engagement.
# *   **Decision Framework:**  Emphasis on “win-win” – prioritizing sustainability and cultural preservation, promoting co-benefits of adaptation.
# *   **Budget Allocation:** $1.05 Billion – Adaptation infrastructure, land use planning, economic resilience projects, cultural heritage conservation, and ongoing community engagement.
#
# **Phase 4:  Monitoring & Adaptive Management (Years 13 - 15) – $400 Million (Highly Variable)**
#
# *   **Goal:**  Continuously evaluate effectiveness, refine strategies, and address unforeseen challenges.
# *   **Actions:**
#     *   **Systematic Data Collection & Analysis (Ongoing):**  Establish a robust monitoring system (satellite imagery, sensor networks, citizen science) to track sea-level rise, erosion rates, and community wellbeing.
#     *   **Regular Performance Reviews (Quarterly):** Assess progress against goals using key metrics (population shifts, economic indicators, environmental health indicators).
#     *   **Policy Adjustments based on Lessons Learned (Quarterly):** Adapting policies and strategies based on data and feedback.
# *   **Objective Criteria:**  Consistent measure of resilience and adaptability; favorable performance indicators related to ecological health and quality of life.
# *   **Decision Framework:**  Agile and responsive – prioritize rapid adjustments based on evolving data and risks.  Develop a clearly defined “exit strategy” outlining how the plan will be reevaluated and adjusted based on emergent circumstances.
# *   **Budget Allocation:**  $400 million -  to track, analyze, and optimize, reliant on continued funding and support.
#
# **III. Detailed Budget Breakdown (Illustrative)**
#
# *   **Emergency Response:** $500 million (Initial preparedness, flood control, emergency shelters)
# *   **Re-location Support:** $200 million (Relocation assistance, workforce training, housing)
# *   **Economic Transition:** $1.5 Billion (Diversification programs, training)
# *   **Climate Adaptation Infrastructure:** $750 million (Adaptive defenses, coastal restoration)
# *   **Cultural Heritage Preservation:** $150 million (Documentation, restoration, community engagement)
# *   **Social Safety Nets:** $300 million (Food security, housing, healthcare)
# *   **Monitoring & Evaluation:** $100 million (Data collection, analysis, reporting)
#
# **IV. Key Metrics & Monitoring Protocols:**
#
# *   **Projections:** Develop detailed, conservative and optimistic projections for population shifts, economic decline, and environmental changes.  Regularly update these projections based on new data.
# *   **Key Indicators:**
#     *   **Sea Level Rise:** Track and monitor sea level rise levels across the predicted vulnerable zones.
#     *   **Population Mobility:** Monitor the number of people moving into and out of protected and relocated areas.
#     *   **Economic Activity:**  Track the economic output and employment rates in relocated areas and areas experiencing retreat.
#     *   **Environmental Health:** Assess air and water quality, biodiversity, and coastal habitat health.
#     *   **Social Capital:** Track community cohesion, social services utilization, and mental health outcomes.
#
# **V. Contingency Planning – 40% Funding Fall**
#
# *   **Scenario 1: 40% Funding Reduction:** Re-prioritize spending to focus on immediate emergency response and strengthening existing resilience measures.  Reduce the scope of relocations.
# *   **Scenario 2: Political Support Reduction:**  Develop a gradual, transparent, and publicly validated exit strategy with clearly defined milestones and potential reassessment criteria.
# *   **Scenario 3:  Shifted Priorities:** Re-evaluate the entire plan to shift resources towards areas with higher resilience potential or those directly impacting vulnerable communities.
#
#
# **VI. Ethical Justification & Key Assumptions:**
#
# *   **Equity:**  A central priority is equitable distribution of resources and benefits across different communities. This will be achieved through:
#     *   **Community Consultation:** Regular, transparent consultations with affected communities are paramount.
#     *   **Data-Driven Justification:** Decision-making will be informed by rigorous data on the impacts of sea-level rise on diverse populations and ecosystems.
#     *   **Prioritize vulnerable populations:**  Retreat and relocation prioritizations will be directed toward those most at risk.
# *   **Cultural Respect:**  Traditional knowledge and cultural heritage are vital for community resilience and adaptation.  Respect will be given to Indigenous communities’ traditional knowledge and ways of life in all planning decisions. Collaborative frameworks will be developed with indigenous groups.
# *   **Transparency:** Open communication and public access to information will be maintained.
#
#
# **VII. Risk & Unintended Consequences:**
#
# *   **Social Disruptions:**  Large-scale displacement could create social unrest and conflict.
# *   **Economic Hardship:**  Economic losses from retreat and relocation could exacerbate existing inequalities.
# *   **Environmental Degradation:**  Rapid retreat could lead to irreversible damage to ecosystems.
# *   **Increased Migration:** Large-scale migration could strain social services and infrastructure.
#
# **VIII. Evaluation & Success Metrics:**
#
# *   **Quantitative:**  Reduction in flood damage, improvement in population density, recovery of key ecosystem services (e.g., fisheries, agriculture), improvement in community wellbeing ratings.
# *   **Qualitative:**  Documented community narratives, stakeholder satisfaction surveys, data on resilience building, and adoption of new technologies.
#
# **This plan is a framework and will require constant adaptation and refinement based on ongoing data and adaptive learning.**
#
# ---
#
# This detailed plan aims for comprehensive planning, prioritizing the well-being of the most vulnerable, while acknowledging the urgency of climate change.  It acknowledges the complexities of coastal resilience through thoughtful planning, focused resource allocation, and the incorporation of cultural sensitivity and community ownership.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Below is a structured, phased 15-year plan intended for a coastal nation of about 4 million people facing projected 20% land-area loss to sea‑level rise within roughly 40 years. It assumes a constant annual national budget equal to 3% of current GDP (real budget envelope grows with GDP; inflation is managed). The plan prioritizes concrete actions, accountable agencies, transparent decision criteria, equitable participation (including vulnerable and Indigenous communities), and explicit contingencies. All components are designed to be publicly justifiable in democratically elected governance and to protect inclusion and rights.
#
# 1) Baseline assumptions and planning parameters (key numbers used throughout)
# - Time horizon: 15 years, with clearly defined phases (see Phase plan below).
# - Population: ~4,000,000.
# - Land loss risk: up to 20% of current coastal land area affected over 40 years; unevenly distributed (some districts near marshes, outlets, deltas, small island geographies, and specific cultural sites at higher risk).
# - Annual budget envelope: 3% of current GDP. All program budgets are expressed as percentages of GDP for planning; actual annual allocations scale with GDP. For illustration, if GDP ≈ $20B, annual envelope ≈ $600M; if GDP ≈ $25B, ≈ $750M, etc.
# - Core cost categories (illustrative share ranges; sum = 100% of the 3% GDP budget each year):
#   - Coastal defenses and risk reduction (structural and nature-based): 35–45%
#   - Managed retreat and relocation costs: 15–25%
#   - Economic resilience programs (livelihood diversification, fisheries adaptation, tourism resilience, etc.): 15–25%
#   - Social safety nets and transitional supports (income support, unemployment, health access): 8–15%
#   - Cultural heritage preservation and adaptation (digitization, protection, relocation of non-replicable assets, community memory programs): 5–10%
# - Decision framework inputs (data sources): hazard maps, erosion and accretion trends, storm surge risk, population vulnerability, asset exposure, cultural significance, governance capacity, and community consent metrics.
# - Valuation methods for nonmarket losses: contingent valuation, choice experiments, ecosystem services valuation, and culturally informed weightings in a transparent, auditable framework.
# - Governance: a cross-ministerial Inclusive Climate Council (ICC) with explicit FPIC (free, prior, informed consent) processes for Indigenous and vulnerable communities; participatory budgeting elements; independent oversight and public reporting.
#
# 2) Governance, inclusion, and decision framework (how communities participate and how decisions are justified)
# - Participating entities:
#   - Ministries: Environment and Climate Change; Infrastructure and Transport; Urban Development and Housing; Fisheries and Maritime Affairs; Culture; Social Welfare; Indigenous and Cultural Affairs Office.
#   - Independent bodies: National Disaster Risk Management Authority; Coastal Protection Authority; National Statistics Office; an independent Coastal Ethics and Oversight Commission (CEOC) with civil society and Indigenous representation; local government associations; and community advisory councils at district/municipal levels.
# - Meaningful inclusion measures:
#   - Establish Indigenous and vulnerable-community councils with real decision rights in planning areas where they are most affected.
#   - FPIC processes with free, prior, informed consent for relocations or significant land-use changes affecting Indigenous peoples and traditional communities; consent decisions must be revisited if risk assessments change materially.
#   - Gender-responsive budgeting and inclusive participation (women, youth, persons with disabilities, migrant workers).
#   - Transparent public consultation with multilingual channels, public dashboards, and accessible forums (digital and in-person).
#   - Capacity-building funds to support community representatives’ technical understanding of climate risks, land-use planning, and compensation mechanisms.
# - Public justification mechanism:
#   - A publicly accessible, annually updated “Coastline Protection and Relocation Rationale” document explaining phase-by-phase decisions, risk thresholds, equity considerations, and the rationale for protecting in place, retreat, or relocating communities.
#   - A standardized scoring rubric (see Phase plan) used in every major decision, with published data sources and sensitivity analyses.
#
# 3) The 15-year phased plan (actions, agencies, timelines, deliverables)
# Phase A: Phase 0–1 (Year 1–Year 2)
# Objectives: Establish governance, gather baseline data, begin community engagement, and initiate protection pilot zones where risk is highest but cost is feasible.
# Actions and responsibilities
# - Establish ICC and CEOC; appoint executive director; set up public dashboards and data portals.
#   - Responsible: Office of the President/Prime Minister; MEC; Cabinet; CEOC; Civil Society Liaison Office.
# - Comprehensive coastal risk mapping and baseline data collection (topography, land cover, population, critical infrastructure, cultural sites, ecosystem services, nonmarket values).
#   - Responsible: National Statistics Office; MEC; Geological/Coastal Survey agencies; Universities.
# - Begin FPIC processes in high-risk districts; establish district-level Coastal Community Councils with gender-balanced representation.
#   - Responsible: Indigenous and Cultural Affairs Office; Local Governments; ICC.
# - Pilot nature-based defenses (two to four small, community-led dune restoration and mangrove rehabilitation projects) in the highest-risk segments; test “living shoreline” approaches.
#   - Responsible: MEC; Coast Protection Authority; Local Governments; forestry/marine agencies.
# - Establish emergency social safety nets readiness and early warning systems; upgrade meteorological & tide gauge networks.
#   - Responsible: National Disaster Risk Management Authority; Ministry of Social Welfare; MET services.
# - Budget: 3% of GDP; initial allocation ~38–42% to Coastal Defenses (pilot scale), 15–25% to Protection pilots, 10–15% to Risk Mapping and Data Infrastructure, 8–12% to Social Safety Net pilots, 5–8% to Cultural Heritage baseline.
#
# Deliverables
# - Baseline vulnerability and risk maps; publicly accessible data portal.
# - FPIC framework finalized and first rounds of district consultations completed.
# - 2–4 pilot nature-based defense projects operational; performance reports.
# - Early warning and communications upgrade plan completed.
#
# Phase B: Phase 2–Phase 3 (Year 3–Year 6)
# Objectives: Scale up protection where feasible; begin more extensive managed retreat pilots; expand economic resilience and social nets; protect cultural heritage where possible.
# Actions and responsibilities
# - Expand coastal defenses (hybrid approaches: hard defences in high-value zones; nature-based measures in buffer zones; improve drainage and flood-proofing).
#   - Responsible: Coast Protection Authority; Ministry of Infrastructure; Local Governments; Community partners.
# - Implement managed retreat pilots in selected neighbourhoods with clear risk gradients and strong community consent; acquire land or easements where feasible; fund relocation to inland zones with basic services.
#   - Responsible: MUDH; MEC; NDMA; Local Governments; Finance Authority.
# - Inland relocation planning: design and construct inland resettlement sites with utilities, schools, clinics, markets; ensure access to livelihoods (e.g., aquaculture supply chain hubs relocated inland, business incubation).
#   - Responsible: MUDH; Ministry of Culture (heritage integration); Fisheries and Maritime Affairs (livelihood continuity).
# - Economic resilience programs: diversify livelihoods (alternative energy, tourism diversification away from high-risk coastlines, fisheries diversification, cold-chain logistics); microfinance and insurance expansion for coastal workers.
#   - Responsible: Ministry of Economic Affairs; Fisheries and Maritime Affairs; Ministry of Culture; Local Governments.
# - Social safety nets: broaden unemployment benefits, health access, housing assistance during relocation, transitional income supports.
#   - Responsible: Ministry of Social Welfare; Health Ministry; MOF (fiscal authority).
# - Cultural heritage: digital documentation and commemoration of heritage sites; where relocation occurs, plan for on-site archival or relocation of movable heritage; engage communities in protecting intangible heritage (song, language, traditional practices).
#   - Responsible: Ministry of Culture; Indigenous and Cultural Affairs Office; Local Cultural Councils.
# - Monitoring and governance: quarterly risk reviews; public dashboards; annual independent audit on equity outcomes and consent processes.
# - Budget: 3% of GDP; approximate allocation: Coastal Defenses 40–50%, Managed Retreat/Relocation 20–25%, Economic Resilience 15–20%, Social Safety Nets 8–12%, Cultural Heritage 5–7%.
#
# Deliverables
# - Expanded defenses in high-risk zones; retreat pilot communities relocated or legally empowered to move.
# - Inland settlement master plans with infrastructure and livelihood linkages.
# - Livelihood diversification programs scaled; insurance schemes accessible to coastal workers.
# - Digitized cultural heritage records; public-facing heritage archive; community memory initiatives.
#
# Phase C: Phase 4–Phase 5 (Year 7–Year 10)
# Objectives: Consolidate protective measures, scale up relocation where consented and feasible, deepen resilience and economic adaptation, and integrate heritage protection with living communities.
# Actions and responsibilities
# - Scale-up “relocation-forward” where communities express clear consent and risk indicates unsustainable in-situ protection; invest in inland infrastructure and service hubs including healthcare, education, and markets.
# - Harden critical infrastructure (roads, ports, power, water) to support adaptation outcomes; continue integrated water management and flood control; expand natural buffers (reforestation of mangroves, barrier reefs where ecologically appropriate).
# - Strengthen seafood value chains and climate-smart fisheries; promote sustainable tourism that is not exposed to the same coastal hazards (e.g., ecotourism inland or in safer coastal belts).
# - Expand financial mechanisms: resilient investment funds, indexed catastrophe bonds if feasible, micro-insurance for households, floodplain land-use transfer programs with clear titling.
# - Cultural heritage adaptation: maintain on-site protection where feasible; relocate critical artifacts and create living museums where relocation is necessary; ensure language and traditional practices are embedded in inland communities.
# - Equity and governance: ongoing FPIC updates; grievance mechanisms; public reporting and citizen oversight.
# - Budget: 3% of GDP; approximate allocation: Coastal Defenses 25–40%, Managed Retreat/Relocation 25–30%, Economic Resilience 20–25%, Social Safety Nets 8–12%, Cultural Heritage 5–7%.
#
# Deliverables
# - Large-scale protective infrastructure where cost-effective; relocation programs with completed land acquisition or relocation plans; inland service hubs functioning with livelihoods integrated.
# - Strengthened value chains for coastal communities; diversified tourism assets; continuing cultural heritage safeguards.
#
# Phase D: Phase 6–Phase 7 (Year 11–Year 13)
# Objectives: Shift toward long-term resilience, adapt to evolving risk, and ensure sustainable living conditions for relocated and in-place communities; prepare for policy sunset or transition.
# Actions
# - Finalize protection and relocation balance across districts with robust public consent documentation; complete sectoral resilience programs; scale back noncritical investments if risk reduced or budget constrained.
# - Maintain surveillance of coastline changes; adapt defenses to cost-effective upgrades; maintain natural buffers to maximize benefits for ecosystem services.
# - Continue funding for social safety nets and ensure equitable access to opportunities in inland areas (education, healthcare, jobs).
# - Heritage programs: consolidate digital stores, maintain local memory centers, formal recognition of community heritage events, and ensure tourism pipelines support heritage preservation.
# - Budget: 3% of GDP with allocation band tightening as necessary; typical shares: Coastal Defenses 20–35%, Managed Retreat/Relocation 25–35%, Economic Resilience 20–25%, Social Safety Nets 8–12%, Cultural Heritage 5–8%.
#
# Deliverables
# - Sustainable balance of defense and retreat; functioning inland communities with preserved livelihoods; ongoing cultural heritage preservation.
#
# Phase E: Phase 8–Phase 9 (Year 14–Year 15)
# Objectives: Evaluation, adaptation, and policy refinement; plan for steady-state governance of coastline resilience, with clear sunset/transition criteria for future budgets and authorities.
# Actions
# - Final policy evaluation; publish comprehensive 15-year report; update risk maps and land-use plans; set next horizon commitments if needed.
# - Institutionalize ongoing citizen oversight and FPIC processes for any future expansions or reconfigurations.
# - Maintain and improve inland livelihoods; ensure equitable outcomes across communities; finalize cultural heritage integration into inland life.
# - Budget: 3% of GDP but with explicit sunset clauses or transition plans, reflecting the long-term viability and projected risk.
#
# Deliverables
# - Publicly accessible 15-year evaluation and a plan for ongoing adaptation beyond Year 15.
#
# 4) Concrete decision framework for protecting in place vs retreat vs relocation (how to make choices, what inputs are used, and how values are included)
# - Core decision criteria (scored for each district/area using a consistent rubric; 0–5 scale for each criterion; total 0–25 or normalized 0–100):
#   - Hazard exposure: current and projected rate of sea‑level rise, storm surge, erosion, flood depth, salinity intrusion.
#   - Vulnerability: population density, reliance on coastal livelihoods, presence of vulnerable groups, displacement risk.
#   - Asset exposure: value of built infrastructure, healthcare, schools, critical facilities, cultural sites; replacement costs.
#   - Cost of protection: estimated cost of defenses to bring risk to an acceptable level; maintenance costs.
#   - Feasibility: engineering feasibility, land availability for retreat/relocation, governance readiness, local support.
#   - Cultural significance: presence and importance of cultural sites, language and heritage, nonmarket values (identity, memorial values).
#   - Equity/Consent: presence of FPIC or consent from affected communities; potential impact on marginalized groups.
#   - Economic impact: effect on livelihoods (fisheries, tourism, transport); potential for alternative livelihoods.
# - Valuation of nonmarket losses and cultural sites:
#   - Cultural significance scores (qualitative input from Indigenous and community stakeholders) combined with contingent valuation surveys and willingness-to-pay measures for preservation of heritage and cultural memory.
#   - Nonmarket ecosystem services: mangrove buffers, coastal protection, nutrient cycling, biodiversity; monetized via ecosystem-services valuation where possible.
#   - Indirect costs and benefits: social cohesion, mental health, community resilience, and intergenerational equity.
# - Decision rules (summary):
#   - Protect in place if hazard exposure is moderate, economic/strategic assets are high-value, feasibility is high, and cultural sites have strong ties to identity; with consent from affected communities.
#   - Retreat if exposure is high-to-severe, protection costs exceed threshold (set ex ante), land for protections is insufficient or untenable, community consent supports relocation, and alternative livelihoods exist.
#   - Relocate if critical infrastructure or large population centers face high risk, cost of protection is prohibitive, and feasible inland sites with services exist; cultural heritage can be preserved via digitization and on-site relocation where possible.
#
# 5) Budget allocation and financing mechanics
# - Annual envelope: 3% of current GDP.
# - Proposed indicative allocation bands (as percent of GDP per year, to be refined when GDP is known):
#   - Coastal defenses and nature-based defense projects: 35–45%
#   - Managed retreat and relocation costs (acquisition, housing, inland service hubs, compensation): 15–25%
#   - Economic resilience programs (livelihood diversification, fisheries adaptation, climate-smart tourism, value chains): 15–25%
#   - Social safety nets and transition supports: 8–12%
#   - Cultural heritage preservation and adaptation: 5–10%
# - Example (illustrative numbers for a $20B GDP baseline; totals 3% ≈ $600M):
#   - Coastal defenses: $210–$270M (35–45%)
#   - Managed retreat/relocation: $90–$150M (15–25%)
#   - Economic resilience: $90–$150M (15–25%)
#   - Social safety nets: $48–$72M (8–12%)
#   - Cultural heritage: $30–$60M (5–10%)
# - Revenue and finance considerations:
#   - Use a mix of annual appropriations, contingent reserves, and legitimate debt instruments for capital-intensive defenses, with clear debt service costs and sunset/return-to-revenue plans.
#   - Explore blended finance: national funds, climate finance facilities, concessional loans, international grants, and public-private partnerships for selective infrastructure and relocation projects.
#   - Ensure fiscal efficiency with competitive procurement, performance-based contracts, and independent audits.
# - Contingency and scaling:
#   - If GDP growth slows, maintain minimum essential protections for high-risk districts; scale back noncritical activities; retain FPIC and equity commitments.
#   - If political support wanes, lock in core protections and safety nets through legal frameworks and transparent public reporting; emphasize citizen oversight.
#
# 6) Measurable metrics, monitoring protocols, and explicit contingency triggers
# - Metrics (annual and phase-based):
#   - Area protected in place (km2) and population protected; number of communities opting to relocate; number of households supported by relocation or insurance; share of critical infrastructure hardened or relocated; number of cultural sites preserved or digitized; employment diversification metrics; poverty rate changes in coastal regions; health access indicators in inland hubs; public satisfaction and consent rates.
#   - Ecosystem services indicators: coastal buffer integrity, mangrove extent, sediment stability, biodiversity indices.
#   - Financial metrics: annual expenditures by category; cost per person protected or relocated; return on investment for livelihood programs.
#   - Governance metrics: FPIC approvals completed; public dashboards updated; number of independent audits; grievance resolution times.
# - Monitoring protocols:
#   - Independent Coastal Outcomes Commission (ICOC) conducts annual audits of program performance, equity outcomes, and consent processes; publishes a comprehensive public report with data access.
#   - Regular hazard monitoring using national sensors, satellite remote sensing, and ground truthing; quarterly risk-reassessment reports; biannual updates to risk maps.
#   - Community-based monitoring with local councils: monthly reports on local conditions, feedback, and concerns; participatory budgeting updates in each district.
#   - Cultural heritage monitoring: independent heritage assessors assess digitization progress, on-site protection status, and community satisfaction with preservation efforts.
# - Contingency triggers that would require strategy shifts (examples):
#   - Trigger A: Hazard exposure or land loss accelerates beyond modeled scenarios (e.g., actual erosion rates exceed the mid-range model by more than 50% for two consecutive years). Action: pause noncritical relocations, accelerate high-value protections in the worst zones, revisit cost-benefit analysis, and potentially reallocate funds to immediate protections.
#   - Trigger B: Budget under-execution or a funding gap >40% of planned annual appropriation. Action: implement a formal scaled-back plan prioritizing high-risk, high-value protections and safety nets; activate contingency financing plans; pause low-priority projects.
#   - Trigger C: Consent failures or significant opposition to relocation in multiple districts; repeated FPIC revocation or protests with clear risks to social stability. Action: re-engage communities with emphasis on benefit sharing, revise compensation, adjust land-use plans, and potentially defer relocations.
#   - Trigger D: Infrastructure failures or severe disaster events indicating unanticipated risk magnitude (e.g., unprecedented storm surge). Action: immediate protective escalations, emergency funding, and rapid design revisions.
#   - Trigger E: Major macroeconomic shock (double-digit recession sustained for 4 quarters). Action: prioritize safety nets and critical services; defer nonessential capital investments; pursue international climate finance where possible.
#   - Trigger F: Inability to protect or relocate certain communities due to land rights complexities or legal obstacles. Action: implement alternative living arrangements, compensation, or cultural preservation by digitization and memory work, while continuing to pursue resolution.
# - Evaluation of success over time:
#   - Annual public reporting against a core dashboard of coverage (area protected, people protected, number of relocations completed, livelihood outcomes), equity metrics (consent rates, benefits for vulnerable groups), and cultural heritage outcomes (sites preserved/digitized).
#   - Mid-term independent review at Year 7 with a revised plan if necessary (reevaluate risk, costs, consent, and equity outcomes).
#   - Final Year 15 evaluation against baseline and target metrics; publish lessons learned and a recommended long-term governance structure for ongoing coastal resilience with explicit sunset/start-up of a new cycle if needed.
#
# 7) Meaningful inclusion and equity in decision-making (how vulnerable and Indigenous communities are included, and how equity is ensured)
# - FPIC throughout: any decision affecting Indigenous communities or areas with high Indigenous significance requires Free, Prior, Informed Consent; community decisions influence options and cost-sharing structures; consent is revisited if risk or circumstances change materially.
# - Governance inclusion:
#   - Seats for Indigenous representatives and vulnerable community leaders in the ICC and CEOC; district-level community advisory councils with gender and disability representation; youth and fisherfolk representation embedded in decisions affecting livelihoods.
#   - Language access, accessible meetings, and culturally appropriate processes; capacity-building funds to help communities understand trade-offs, costs, and compensation schemes.
# - Equity safeguards:
#   - Equity impact assessments for all major decisions; targeted support for the most vulnerable (low-income households, women, elderly, people with disabilities) during relocation or transition.
#   - Guaranteed livelihood options in inland settlements (jobs, schooling, healthcare, market access) and consistent access to social safety nets for at least a defined transition period.
#   - Transparent grievance mechanisms with independent mediation and appeal processes; clear compensation standards for land acquisitions and livelihood losses.
# - Cultural heritage and Indigenous rights:
#   - Prioritization of preservation and respectful relocation options for heritage and cultural sites; digital archiving and community-led interpretation of heritage; involvement of community guardians in protecting intangible cultural heritage (language, songs, ritual practices).
#
# 8) Ethical justification of trade-offs, key assumptions, risks, and an alternate contingency plan
# - Ethical justification:
#   - Protecting lives, livelihoods, and basic rights in the face of climate risk is a legitimate state obligation in a democracy; actions are designed to minimize coercive displacement, maximize community consent, and provide fair compensation and alternative livelihoods.
#   - The plan prioritizes least-disruption approaches consistent with consent (protect in place where feasible, retreat only where necessary, and relocate with meaningful community input and support). It also prioritizes cultural heritage preservation, memory, and identity as essential components of a just transition.
# - Key quantitative assumptions (explicit):
#   - SLR and hazard projections are based on mid-range IPCC-style scenarios with sensitivity analyses.
#   - 20% of coastal land area is at risk over 40 years; distributions by district follow current exposure patterns; defense costs are within ranges for hybrid nature-based and structural defenses; relocation costs reflect land acquisition, housing, and inland service development.
#   - 3% GDP annual budget envelope with adjustments for inflation; finance costs and debt service considered where capital investments are debt-funded; government will maintain social safety nets to protect vulnerable groups.
#   - Nonmarket losses and cultural values can be quantified via a combination of contingent valuation and ecosystem-service valuation methods, with strong community input to weight cultural factors.
# - Main risks and unintended consequences:
#   - Inequitable outcomes if consent is unevenly achieved, or if relocation creates new forms of marginalization (e.g., in-migration to inland districts overwhelming services).
#   - Economic risks if defense investments fail to deliver expected protection or if relocation disrupts livelihoods without viable alternatives; potential for “double exposure” where defenses induce growth in risky areas.
#   - Environmental risks if hard defenses cause erosion of other areas, degrade natural buffers, or alter sediment transport; ecosystem disruption could occur if nature-based solutions are not properly designed.
#   - Governance and political risks: public trust could erode if costs, benefits, or consent processes appear opaque; delays in land acquisition or permitting could derail timelines.
# - Alternate contingency plan for a 40% funding cut or reduced political support:
#   - Prioritize core safety-net guarantees and high-risk protections; defer nonessential resilience investments; accelerate innovations that deliver high leverage with lower costs (e.g., targeted nature-based approaches, community-led defenses, and low-cost monitoring).
#   - Scale-back relocation by focusing first on districts where risk is highest and consent is strongest; adopt incremental, low-cost relocation options (e.g., shared facilities, phased transitions, and mixed-use inland hubs).
#   - Seek alternative financing: climate finance facilities, international grants, concessional loans, and public-private partnerships for selected high-impact projects with clear risk-sharing and performance metrics.
#   - Strengthen governance and transparency: maintain public dashboards, publish rapid-assessment reports, and maintain a citizen oversight body to sustain legitimacy during constrained periods.
#   - Reassess risk, re-prioritize allocations, and publish an updated, publicly justified plan with revised timelines and targets.
#
# 9) How success would be evaluated and how to adapt over time
# - Short-term (Year 1–Year 3): Baseline risk maps completed; FPIC processes underway; pilot defenses and relocation pilots initiated; dashboards and reporting system operational; pillars of social safety nets established.
# - Medium-term (Year 4–Year 6): Expansion of defenses in high-risk zones; relocation pilots progressing; inland service hubs functional; diversified livelihoods in place; heritage digitization completed for key sites; governance and consent processes institutionalized.
# - Long-term (Year 7–Year 15): Consolidated protective and relocation framework; resilient livelihoods across inland zones; cultural heritage preserved and integrated; risk monitoring and governance sustainability assured; plan for ongoing adaptation beyond Year 15.
# - Success indicators:
#   - Reduced annual exposure and number of people at risk; proportion of critical infrastructure protected or relocated; stable or improving livelihoods in coastal and inland communities; strong indicators of equity (consent rates, participation, and benefits for vulnerable groups); heritage preservation outcomes; public trust and transparent governance metrics.
# - Transparent reporting:
#   - Annual “State of the Coast” report with public dashboards; independent reviews at mid-term and end-term; open data in machine-readable formats to enable external analysis and public scrutiny.
#
# 10) Summary of deliverables and responsibilities by sector
# - Governance and inclusion
#   - ICC, CEOC, FPIC processes, district community councils; public dashboards; independent audits.
# - Engineering and protection
#   - Coastal Protection Authority; Ministry of Infrastructure; local governments; nature-based solution pilots; critical infrastructure upgrades.
# - Relocation and settlements
#   - Ministry of Urban Development and Housing; land acquisition and resettlement planning; inland service hubs; livelihood linkages.
# - Economic resilience and livelihoods
#   - Ministry of Economic Affairs; Fisheries and Maritime Affairs; tourism diversification; insurance and microfinance programs.
# - Social safety nets
#   - Ministry of Social Welfare; health services; affordable housing in inland hubs; social protection programs.
# - Cultural heritage and Indigenous rights
#   - Ministry of Culture; Indigenous and Cultural Affairs Office; heritage digitization; commemorative and memory initiatives; FPIC oversight.
# - Monitoring and accountability
#   - ICOC; National Statistics Office; NDMA; independent auditors; public reporting.
#
# If you would like, I can convert this into a concrete year-by-year action plan with explicit budget lines (in local currency and in terms of GDP percentages), a scoring rubric template for the protection/retreat/relocation decision, and a set of sample dashboards and data requests to share publicly. I can also adapt the plan to a hypothetical GDP figure (e.g., $20B vs. $30B) to illustrate annual budget magnitudes and project costs in more precise terms.
#
# # Response from competitor 2
#
# As Chief Advisor, I present this 15-year plan for our coastal nation of 4 million people, facing the existential threat of losing 20% of its land area to sea-level rise (SLR) within 40 years. This plan is designed to be publicly justifiable, protect democratic inclusion, and leverage our annual budget of 3% of current GDP (approx. $4.8 billion per year).
#
# ---
#
# ### **A Resilient Future: A 15-Year National Adaptation Plan for Sea-Level Rise**
#
# **Core Vision:** To transform our nation into a global leader in climate adaptation, safeguarding our people, culture, and economy through strategic protection, managed retreat, and innovative resilience, ensuring a just and equitable transition for all.
#
# **Guiding Principles:**
# 1.  **People First:** Prioritizing the safety, well-being, and dignity of our citizens.
# 2.  **Justice & Equity:** Fair distribution of burdens and benefits, especially for vulnerable and Indigenous communities.
# 3.  **Transparency & Accountability:** Open decision-making, data-driven policies, and continuous public engagement.
# 4.  **Economic Reinvention:** Building a vibrant, climate-resilient economy that fosters new opportunities.
# 5.  **Cultural Stewardship:** Preserving our unique heritage, both tangible and intangible.
# 6.  **Adaptive Governance:** Flexibility to adjust strategies based on evolving science and on-the-ground realities.
#
# **Contextual Assumptions:**
# *   **Population:** 4 million
# *   **Assumed Current GDP:** $160 Billion (approx. $40,000 per capita)
# *   **Annual Budget Allocation:** 3% of GDP = **$4.8 Billion/year**
# *   **Total 15-Year Budget:** **$72 Billion**
# *   **Sea Level Rise Projection:** High-end scenario, implying an aggressive rate of inundation and erosion, leading to 20% land loss in 40 years.
# *   **Political Will:** Strong initial national consensus and sustained political commitment.
#
# ---
#
# ### **Part 1: Prioritized, Phased 15-Year Plan**
#
# The plan is divided into three 5-year phases, each building upon the previous, with continuous monitoring and adaptation.
#
# **Phase 1: Foundation, Assessment & Pilot Implementation (Years 1-5)**
# *   **Goal:** Establish legal, institutional, and data foundations; foster public understanding and engagement; conduct detailed assessments; initiate pilot projects.
# *   **Annual Budget Allocation:** $4.8 Billion
#
# | Action Area                        | Concrete Actions                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Responsible Agencies                                                                                                                    | Timeline    |
# | :--------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :-------------------------------------------------------------------------------------------------------------------------------------- | :---------- |
# | **1.1 Governance & Legal Framework** | - Establish a **National Coastal Adaptation Authority (NCAA)** as the central coordinating body. <br> - Enact a comprehensive **Coastal Adaptation Act (CAA)**, defining mandates for adaptation, land use, compensation, and eminent domain for retreat. <br> - Amend zoning regulations for "no-build" and "retreat-ready" designations in at-risk areas.                                                                                                            | Ministry of Justice, Ministry of Environment, NCAA (once established), Parliament                                                     | Y1-Y2       |
# | **1.2 Data & Risk Assessment**     | - Conduct high-resolution LiDAR mapping, bathymetric surveys, and dynamic SLR modeling for the entire coastline (priority on high-risk zones). <br> - Map all critical infrastructure, cultural sites, and population density within projected inundation zones. <br> - Establish a national multi-hazard early warning system.                                                                                                                                     | Ministry of Environment, National Geographic Institute, Meteorological Agency, NCAA                                                     | Y1-Y3       |
# | **1.3 Public Engagement & Awareness**| - Launch "Our Shifting Shores" public education campaign (media, schools, community workshops). <br> - Establish **Regional Adaptation Councils (RACs)** with diverse community and Indigenous representation. <br> - Create an interactive online portal for data, planning, and feedback.                                                                                                                                                                           | Ministry of Information, Ministry of Education, NCAA, Local Governments                                                                 | Ongoing (Y1-Y15) |
# | **1.4 Economic & Social Resilience**| - Assess national economic vulnerability to SLR (fisheries, tourism, agriculture, ports). <br> - Initiate pilot skills training programs for emerging green and blue economy sectors. <br> - Develop a national digital infrastructure blueprint to support economic decentralization.                                                                                                                                                                             | Ministry of Economy, Ministry of Labor, NCAA                                                                                            | Y2-Y5       |
# | **1.5 Pilot Projects**             | - Implement 2-3 "Protect in Place" pilot projects (e.g., mangrove restoration, small-scale dykes) in diverse communities. <br> - Execute 1-2 small-scale "Managed Retreat/Relocation" pilot projects, emphasizing voluntary participation, comprehensive compensation, and social support. <br> - Document lessons learned and best practices.                                                                                                                             | NCAA, Ministry of Infrastructure, Local Governments, Community Groups                                                                   | Y3-Y5       |
# | **1.6 Cultural Heritage Mapping**  | - Comprehensive mapping, documentation, and vulnerability assessment of all tangible and intangible cultural sites in threatened zones, in partnership with Indigenous communities. <br> - Develop emergency salvage and preservation protocols.                                                                                                                                                                                                                             | Ministry of Culture, Indigenous Affairs Department, NCAA                                                                                | Y1-Y3       |
#
# **Phase 2: Scaling Up & Major Infrastructure (Years 6-10)**
# *   **Goal:** Implement large-scale adaptation projects; accelerate managed retreat and relocation; bolster economic resilience and social safety nets.
# *   **Annual Budget Allocation:** $4.8 Billion
#
# | Action Area                        | Concrete Actions                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Responsible Agencies                                                                                                                    | Timeline    |
# | :--------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :-------------------------------------------------------------------------------------------------------------------------------------- | :---------- |
# | **2.1 Coastal Defenses (Protect)** | - Begin construction of priority hard defenses (sea walls, surge barriers) for critical economic hubs, major cities, and identified "protect-in-place" communities. <br> - Scale up nature-based solutions (mangrove restoration, coral reefs, dune systems) in suitable areas. <br> - Implement strategic beach nourishment programs.                                                                                                                                      | Ministry of Infrastructure, NCAA, Ministry of Environment                                                                               | Y6-Y10      |
# | **2.2 Managed Retreat & Relocation**| - Initiate the first wave of large-scale, voluntary managed retreat and strategic relocation for identified communities. <br> - Develop "Receiving Communities" with necessary infrastructure and services in designated upland areas. <br> - Establish a national land bank for future relocation and ecosystem restoration. <br> - Provide comprehensive financial, housing, and social support for relocating families and businesses.                                      | NCAA, Ministry of Housing, Ministry of Social Welfare, Local Governments, Land Affairs Agency                                         | Y6-Y10      |
# | **2.3 Economic Transformation**    | - Establish Special Economic Zones (SEZs) in inland areas focused on climate-resilient industries (e.g., advanced manufacturing, agri-tech, renewable energy, sustainable aquaculture). <br> - Provide grants and low-interest loans for businesses to relocate or transition to resilient sectors. <br> - Invest in R&D for climate adaptation technologies.                                                                                                                     | Ministry of Economy, NCAA, National Innovation Agency                                                                                   | Y6-Y10      |
# | **2.4 Social Safety Nets**         | - Expand national social safety nets to cover climate-induced displacement and income loss (e.g., unemployment, housing assistance). <br> - Establish mental health and psychosocial support services for affected communities. <br> - Develop robust educational integration programs for relocated children.                                                                                                                                                             | Ministry of Social Welfare, Ministry of Health, Ministry of Education, NCAA                                                             | Y6-Y10      |
# | **2.5 Cultural Heritage Protection**| - Begin strategic relocation/salvage of highly vulnerable tangible cultural artifacts and archives. <br> - Implement advanced digital preservation of intangible heritage (oral histories, traditions) with community involvement. <br> - Co-design preservation strategies for sacred sites with Indigenous communities.                                                                                                                                              | Ministry of Culture, Indigenous Affairs Department, NCAA, National Archives                                                             | Y6-Y10      |
#
# **Phase 3: Full-Scale Adaptation & Long-Term Transition (Years 11-15)**
# *   **Goal:** Consolidate adaptation efforts, ensure long-term sustainability, and continuously monitor and adjust strategies for enduring resilience.
# *   **Annual Budget Allocation:** $4.8 Billion
#
# | Action Area                        | Concrete Actions                                                                                                                                                                                                                                                                                                                                                                                                                                                         | Responsible Agencies                                                                                                                    | Timeline    |
# | :--------------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :---------- |
# | **3.1 Integrated Coastal Management**| - Fully operationalize the NCAA as the primary coordinating body for all adaptation efforts. <br> - Implement adaptive management protocols for all coastal defenses, ensuring maintenance and upgrades based on evolving SLR projections. <br> - Establish a permanent national fund for long-term coastal resilience and emergency response.                                                                                                                             | NCAA, Ministry of Finance                                                                                                               | Y11-Y15     |
# | **3.2 Sustained Retreat & Relocation**| - Continue large-scale managed retreat and strategic relocation, integrating lessons learned from previous phases. <br> - Focus on land-use planning in receiving areas to prevent future displacement. <br> - Conduct post-relocation impact assessments to ensure successful integration and well-being of relocated communities.                                                                                                                                         | NCAA, Ministry of Housing, Local Governments                                                                                            | Y11-Y15     |
# | **3.3 Resilient Economy & Infrastructure**| - Support the full transition of the national economy towards climate-resilient and sustainable sectors. <br> - Invest in resilient infrastructure (e.g., climate-proofed transportation, decentralized energy grids, water systems). <br> - Promote blue/green economy initiatives in newly restored coastal ecosystems.                                                                                                                                             | Ministry of Economy, Ministry of Infrastructure, NCAA                                                                                   | Y11-Y15     |
# | **3.4 Enhanced Social Cohesion**   | - Implement programs to foster social cohesion between original residents and relocated communities. <br> - Develop specific support for elderly, disabled, and other vulnerable groups in the transition process. <br> - Establish permanent, independent grievance mechanisms for adaptation-related issues.                                                                                                                                                              | Ministry of Social Welfare, Local Governments, NCAA                                                                                     | Y11-Y15     |
# | **3.5 Legacy & Future Planning**   | - Establish national memorials and digital archives for lost landscapes and heritage. <br> - Develop a long-term (50-100 year) national vision for a post-SLR resilient nation, including land use and demographic projections. <br> - Continuously update scientific projections and adaptation strategies based on global best practices and local monitoring.                                                                                                              | NCAA, Ministry of Culture, National Planning Commission                                                                                 | Y11-Y15     |
#
# ---
#
# ### **Part 2: Objective Criteria and Transparent Decision Framework**
#
# Decisions to protect, retreat, or relocate are profound. Our framework employs a multi-criteria analysis (MCA) with expert assessment and extensive community consultation, overseen by the NCAA. The weighting of criteria will be finalized through public dialogue.
#
# **Decision Categories:**
# 1.  **Protect in Place (High-Value Retention):** Maintain current location with significant coastal defenses.
# 2.  **Managed Retreat (Strategic Relocation):** Phased, planned movement of communities and infrastructure from vulnerable areas.
# ...
#
# **Alternate Contingency Plan (40% Funding Cut or Reduced Political Support):**
#
# If annual funding falls by **40%** (to $2.88 Billion) or political support significantly diminishes, the plan must pivot to a survival-focused approach.
#
# *   **Re-prioritization Logic:** Shift from "optimize for long-term resilience and equity" to "minimize immediate human suffering and safeguard critical national functions."
# *   **Strategic Adjustments:**
#     *   **Coastal Defenses:** Limit to absolutely essential infrastructure protecting national strategic assets (capital city, primary port, power generation). Halt new large-scale hard defense projects. Prioritize cost-effective nature-based solutions.
#     *   **Managed Retreat & Relocation:** Prioritize only communities in imminent danger or those with the highest vulnerability/lowest relocation cost. Voluntary aspects would be curtailed, shifting towards more directive, though compensated, processes.
#     *   **Minimalist Relocation Support:** Compensation would shift from "fair market value + premium" to "fair market value only" or basic housing and livelihood support. Social safety nets would focus on emergency aid.
#     *   **Economic Programs:** Focus on essential retraining for displaced populations. Halt grants for new climate-resilient industries.
#     *   **Cultural Heritage:** Focus solely on digital documentation and emergency salvage of irreplaceable items. Long-term preservation deferred.
#     *   **Leaner Governance:** Significant reduction in NCAA staffing and outreach, focusing on core coordination and emergency response.
# *   **Ethical Implications:** This contingency would necessitate starker trade-offs, prioritizing survival and minimizing harm over optimal well-being and comprehensive equity. It acknowledges that not everyone can be helped equally when resources are severely constrained, shifting towards a **Triage** ethical framework.
# *   **Evaluation of Success in Contingency:** Success would be redefined as minimizing loss of life, maintaining basic governance, preventing widespread social collapse, and protecting core national assets. Metrics would focus on humanitarian aid delivery, lives saved, and maintenance of essential services.
#
# **How to Evaluate Success Over Time:**
#
# Evaluation is continuous, iterative, and adaptive across all phases:
#
# *   **Short-Term (Years 1-5):** Success is judged by establishing foundational elements: legal frameworks enacted, NCAA operational, high-res mapping completed (e.g., 90% coverage), public awareness increased (e.g., 70% understanding), pilot projects initiated, and community feedback integrated.
#     *   **Evaluation:** Annual NCAA reports, parliamentary oversight, public satisfaction surveys on information dissemination.
# *   **Mid-Term (Years 6-10):** Success is judged by scaling up implementation and showing initial impact: X communities protected/relocated, Y hectares defended, Z jobs created, Q% reduction in displacement-related poverty, cultural sites digitally documented.
#     *   **Evaluation:** Biennial independent audits, scientific review panels, community outcome surveys (relocation satisfaction, access to services), economic impact assessments.
# *   **Long-Term (Years 11-15 & Beyond):** Success is judged by achieving sustainable resilience and a transformed nation: overall reduction in vulnerability (e.g., 50% less population at high risk than baseline), sustained economic growth in climate-resilient sectors, high social cohesion in new communities, all critical cultural heritage protected or documented, and enhanced national capacity to adapt to future SLR.
#     *   **Evaluation:** Comprehensive 15-year plan review against original objectives, independent socio-economic and environmental impact studies, comparison with international best practices, long-term well-being indicators, and intergenerational equity assessments.
#
# This adaptive approach ensures that our nation remains agile and effective in confronting the ongoing challenge of sea-level rise, building a resilient and equitable future for all.
#
# # Response from competitor 3
#
# Okay, here’s a detailed, phased 15-year plan designed to address the projected loss of land area due to sea-level rise in a 4 million population coastal nation, prioritizing democratic inclusion, public justification, and long-term resilience. This plan acknowledges the complexity, the need for adaptation, and leverages a cautious, proactive approach.
#
# **I. Executive Summary:**
#
# This plan acknowledges the escalating threat of sea-level rise and aims to mitigate its worst effects through a multi-pronged approach prioritizing community protection, economic stability, cultural preservation, and social equity.  The $3% of GDP annual budget is a realistic constraint, requiring careful prioritization and strategic allocation.  Transparency and public justification are fundamental.  Success is measured through a combination of quantifiable metrics, rigorous monitoring, and flexible contingency plans.
#
# **II. Prioritized Phased Plan (15 Years)**
#
# **Phase 1: Assessment & Initial Response (Years 1-3) – $1.5 Billion (Approx. 20% - Adjust Based on Initial Data)**
#
# *   **Goal:** Establish a baseline understanding, initiate immediate protective measures, and build initial community trust.
# *   **Actions:**
#     *   **Coastal Mapping & Vulnerability Assessment (Q1-Q3):**  Deploy drones and GIS specialists to create detailed maps of vulnerable coastal areas, identifying specific risks (e.g., erosion patterns, high-risk zones). Conduct detailed socio-economic assessments of affected communities.
#     *   **Emergency Resilience Infrastructure (Q2-Q4):**  Establish regional, localized flood defenses (levees, seawalls – prioritizing strategic placement to minimize negative impacts on farmland and critical infrastructure).  Create early warning systems.
#     *   **Community Engagement & Education (Q1-Q3):**  Launch town hall meetings, online forums, and public awareness campaigns promoting climate adaptation and relocation strategies.  Focus on communicating the potential impacts clearly and empathetically.
#     *   **Initial Retreat Planning (Q3-Q4):**  Form a stakeholder panel consisting of representatives from local governments, communities, environmental experts, and economists to establish the initial scale of retreat zones and develop specific relocation strategies.
# *   **Objective Criteria:**  Documented vulnerability assessments; initial flood defense infrastructure presence; baseline understanding of community priorities; community engagement levels.
# *   **Decision Framework:**  Weighted scoring based on risk assessment, social impact, economic necessity, and community consensus.  Transparency in assessment methodology.
# *   **Budget Allocation:**  $600 Million – Emergency response, mapping, initial defenses, education, and relocation planning.
#
# **Phase 2:  Strategic Retreat & Economic Transition (Years 4-7) – $3 Billion (Approx. 40% - Adjust Based on Retreat Impact)**
#
# *   **Goal:**  Reduce vulnerability through targeted retreat, facilitate economic diversification, and address social impacts.
# *   **Actions:**
#     *   **Targeted Retreat Implementation (Q1-Q4):**  Implement relocation plans for the most vulnerable populations based on the previous phase’s findings and updated projections. Prioritize communities with higher concentrations of vulnerable populations and critical infrastructure.  Focus on creating “smart” retreats – resilient but adaptable communities.
#     *   **Economic Diversification Support (Q1-Q4):**  Provide grants and tax incentives to businesses that relocate or adopt new industries.  Offer vocational training programs to support this transition. Focus on sustainable tourism, aquaculture, and new green technologies.
#     *   **Land Use Planning Updates (Q2-Q4):**  Re-evaluate land use regulations – moving away from continuous coastal development towards zones with higher natural vegetation cover and protection.
#     *   **Social Safety Net Enhancement (Q2-Q4):**  Strengthen social safety net programs (food assistance, housing assistance, healthcare) to support those displaced or struggling to adapt.  Ensure culturally appropriate support systems.
# *   **Objective Criteria:**  Reduced population density in retreat zones; demonstrable economic growth within relocated areas; progress towards social safety net adequacy.
# *   **Decision Framework:**  Focus on “just” – equitable distribution of resources across affected communities. Transparency linked to equitable restoration and cultural preservation.  Regular feedback and review from impacted groups.
# *   **Budget Allocation:** $1.75 Billion – Relocation assistance, economic transition funds, support services, environmental restoration.
#
# **Phase 3: Adaptive Resilience & Long-Term Planning (Years 8-12) – $1.2 Billion (Approx. 30% - Adjusted based on retreat impacts)**
#
# *   **Goal:** Optimize adaptation strategies, implement long-term infrastructure, and deepen community engagement.
# *   **Actions:**
#     *   **Adaptation Infrastructure – Smart Coastal Barriers (Q1-Q4):** Focus on adaptive sea defenses (drones, modular flood barriers) that can be adjusted and maintained based on data.
#     *   **Climate-Resilient Agriculture (Q1-Q4):** Invest in supporting local, sustainable agricultural practices – aquaculture, seaweed farming, micro-nutrient agriculture – to build economic resilience.
#     *    **Cultural Heritage Protection (Q2-Q4):** Establish a dedicated safeguarding fund, collaborate with local experts to catalog and document heritage sites.
#     *    **Community Consultation (Ongoing):** Implement regular, transparent community consultations on all long-term adaptation plans.
# *   **Objective Criteria:**   Reduced risk of climate impacts; successful implementation of adaptation plans; sustained community engagement.
# *   **Decision Framework:**  Emphasis on “win-win” – prioritizing sustainability and cultural preservation, promoting co-benefits of adaptation.
# *   **Budget Allocation:** $1.05 Billion – Adaptation infrastructure, land use planning, economic resilience projects, cultural heritage conservation, and ongoing community engagement.
#
# **Phase 4:  Monitoring & Adaptive Management (Years 13 - 15) – $400 Million (Highly Variable)**
#
# *   **Goal:**  Continuously evaluate effectiveness, refine strategies, and address unforeseen challenges.
# *   **Actions:**
#     *   **Systematic Data Collection & Analysis (Ongoing):**  Establish a robust monitoring system (satellite imagery, sensor networks, citizen science) to track sea-level rise, erosion rates, and community wellbeing.
#     *   **Regular Performance Reviews (Quarterly):** Assess progress against goals using key metrics (population shifts, economic indicators, environmental health indicators).
#     *   **Policy Adjustments based on Lessons Learned (Quarterly):** Adapting policies and strategies based on data and feedback.
# *   **Objective Criteria:**  Consistent measure of resilience and adaptability; favorable performance indicators related to ecological health and quality of life.
# *   **Decision Framework:**  Agile and responsive – prioritize rapid adjustments based on evolving data and risks.  Develop a clearly defined “exit strategy” outlining how the plan will be reevaluated and adjusted based on emergent circumstances.
# *   **Budget Allocation:**  $400 million -  to track, analyze, and optimize, reliant on continued funding and support.
#
# **III. Detailed Budget Breakdown (Illustrative)**
#
# *   **Emergency Response:** $500 million (Initial preparedness, flood control, emergency shelters)
# *   **Re-location Support:** $200 million (Relocation assistance, workforce training, housing)
# *   **Economic Transition:** $1.5 Billion (Diversification programs, training)
# *   **Climate Adaptation Infrastructure:** $750 million (Adaptive defenses, coastal restoration)
# *   **Cultural Heritage Preservation:** $150 million (Documentation, restoration, community engagement)
# *   **Social Safety Nets:** $300 million (Food security, housing, healthcare)
# *   **Monitoring & Evaluation:** $100 million (Data collection, analysis, reporting)
#
# **IV. Key Metrics & Monitoring Protocols:**
#
# *   **Projections:** Develop detailed, conservative and optimistic projections for population shifts, economic decline, and environmental changes.  Regularly update these projections based on new data.
# *   **Key Indicators:**
#     *   **Sea Level Rise:** Track and monitor sea level rise levels across the predicted vulnerable zones.
#     *   **Population Mobility:** Monitor the number of people moving into and out of protected and relocated areas.
#     *   **Economic Activity:**  Track the economic output and employment rates in relocated areas and areas experiencing retreat.
#     *   **Environmental Health:** Assess air and water quality, biodiversity, and coastal habitat health.
#     *   **Social Capital:** Track community cohesion, social services utilization, and mental health outcomes.
#
# **V. Contingency Planning – 40% Funding Fall**
#
# *   **Scenario 1: 40% Funding Reduction:** Re-prioritize spending to focus on immediate emergency response and strengthening existing resilience measures.  Reduce the scope of relocations.
# *   **Scenario 2: Political Support Reduction:**  Develop a gradual, transparent, and publicly validated exit strategy with clearly defined milestones and potential reassessment criteria.
# *   **Scenario 3:  Shifted Priorities:** Re-evaluate the entire plan to shift resources towards areas with higher resilience potential or those directly impacting vulnerable communities.
#
#
# **VI. Ethical Justification & Key Assumptions:**
#
# *   **Equity:**  A central priority is equitable distribution of resources and benefits across different communities. This will be achieved through:
#     *   **Community Consultation:** Regular, transparent consultations with affected communities are paramount.
#     *   **Data-Driven Justification:** Decision-making will be informed by rigorous data on the impacts of sea-level rise on diverse populations and ecosystems.
#     *   **Prioritize vulnerable populations:**  Retreat and relocation prioritizations will be directed toward those most at risk.
# *   **Cultural Respect:**  Traditional knowledge and cultural heritage are vital for community resilience and adaptation.  Respect will be given to Indigenous communities’ traditional knowledge and ways of life in all planning decisions. Collaborative frameworks will be developed with indigenous groups.
# *   **Transparency:** Open communication and public access to information will be maintained.
#
#
# **VII. Risk & Unintended Consequences:**
#
# *   **Social Disruptions:**  Large-scale displacement could create social unrest and conflict.
# *   **Economic Hardship:**  Economic losses from retreat and relocation could exacerbate existing inequalities.
# *   **Environmental Degradation:**  Rapid retreat could lead to irreversible damage to ecosystems.
# *   **Increased Migration:** Large-scale migration could strain social services and infrastructure.
#
# **VIII. Evaluation & Success Metrics:**
#
# *   **Quantitative:**  Reduction in flood damage, improvement in population density, recovery of key ecosystem services (e.g., fisheries, agriculture), improvement in community wellbeing ratings.
# *   **Qualitative:**  Documented community narratives, stakeholder satisfaction surveys, data on resilience building, and adoption of new technologies.
#
# **This plan is a framework and will require constant adaptation and refinement based on ongoing data and adaptive learning.**
#
# ---
#
# This detailed plan aims for comprehensive planning, prioritizing the well-being of the most vulnerable, while acknowledging the urgency of climate change.  It acknowledges the complexities of coastal resilience through thoughtful planning, focused resource allocation, and the incorporation of cultural sensitivity and community ownership.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2", "3"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
print(results_dict)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# {'results': ['1', '2', '3']}
# Rank 1: gpt-5-nano
# Rank 2: gemini-2.5-flash
# Rank 3: gemma3:1b-it-qat

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
