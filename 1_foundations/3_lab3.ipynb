# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# House near electricity rest house,
# Bilaspur
# Distt. Bilaspur
# Himachal Pradesh
# PIN:174001
# 9115944889 (Home)
# anshuambuj@gmail.com
# www.linkedin.com/in/
# ambujshandil14 (LinkedIn)
# travel-app-indus.herokuapp.com/
# contactus (Personal)
# resume-ambuj.herokuapp.com/
# home (Personal)
# Top Skills
# GenAi
# Reactjs
# Problem Solving
# Certifications
# Unsupervised Learning,
# Recommenders, Reinforcement
# Learning
# Machine Learning
# Advanced Learning Algorithms
# Ambuj Shandil
# Lead Software Engineer | Java | Spring Boot | Angular | Exploring
# LLMs, RAG, and Agentic AI
# Bengaluru, Karnataka, India
# Summary
# A seasoned full-stack developer with over a decade of expertise
# in designing and developing web applications. A passionate and
# dedicated learner, proficient in a wide array of technologies including
# Java, JavaScript, TypeScript, Python, Spring Batch, Spring MVC,
# Spring Boot, Spring JPA, Angular, ReactJS, Bootstrap, JPA,
# JDBC, Maven, Gradle, JIRA, Bitbucket, Jenkins, Git, Jest, Enzyme,
# Hibernate, PCF, and more.
# Currently exploring the cutting-edge world of Large Language
# Models (LLMs), Retrieval-Augmented Generation (RAG), and
# agentic AI, applying hands-on projects to combine my backend and
# full-stack expertise with the latest generative AI innovations.
# Experience
# Morgan Stanley
# Senior Software Engineer
# June 2022 - Present (3 years 9 months)
# Bangalore Urban, Karnataka, India
# A seasoned full-stack developer boasting over a decade of expertise in crafting
# web applications. A passionate and dedicated learner, proficient in a wide
# array of technologies including  GenAI,  Java  ,JavaScript Spring Batch, Spring
# MVC, Spring Boot, Spring JPA, JSP, HTML5, CSS3,  Angular 13 , Bootstrap, ,
# Maven, Gradle, JIRA, Bitbucket, Jenkins, Git Hibernate, PCF, and more.
# Wells Fargo
# Senior Software Engineer
# December 2019 - June 2022 (2 years 7 months)
# Bengaluru, Karnataka, India
# Passionate Fullstack developer with more than 8 years of experience in
# developing web applications and microservices. The primary role of developing
# microservices using spring boot rest, PCF, Solace, spring batch, etc. Involved
# in requirement analysis, testing, deploying the deliverables. An avid learner
#   Page 1 of 2
# having hands-on in various technologies and tools like JAVA 8, JavaScript,
# Spring MVC, Spring Boot, Spring batch, JSP, REACTJS, Angular 4/5/6,
# Bootstrap, JPA, JDBC, Hibernate, Maven, JIRA, Bit bucket, Jenkins, GIT, Jest,
# Enzyme, Oracle 19c, HTML5, CSS3, Junit, Mockito.
# Infosys
# Technology Analyst
# March 2013 - November 2019 (6 years 9 months)
# Bangalore, India
# Passionate Fullstack developer with more than 6 years of experience in
# developing web applications. An avid learn having hands-on in various
# technologies and tools like JAVA 6/7/8, JavaScript, Spring portlets, Spring
# MVC, Spring Boot, Servlets, JSP, REACTJS, Angular 4/5/6, Bootstrap, JPA,
# JDBC, Hibernate, Maven, JIRA, Bit bucket, Jenkins, GIT, Jest, Enzyme,
# OpenShift, Aws, DB2, HTML5, CSS3, Junit.
# Education
# National Institute of Technology Hamirpur
# Bachelor of Technology (B.Tech.), Electronics and Communication
# Engineering · (2008 - 2012)
#   Page 2 of 2

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Ambuj Shandil"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Ambuj Shandil. You are answering questions on Ambuj Shandil's website, particularly questions related to Ambuj Shandil's career, background, skills and experience. Your responsibility is to represent Ambuj Shandil for interactions on the website as faithfully as possible. You are given a summary of Ambuj Shandil's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Ambuj Shandil. I'm a Software Engineer. I'm originally from Bilaspur, Himachal, but currently I am in Banglaore.\nI love all foods, particularly French food, but strangely I'm repelled by almost all forms of cheese. I'm not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nHouse near electricity rest house,\nBilaspur\nDistt. Bilaspur\nHimachal Pradesh\nPIN:174001\n9115944889 (Home)\nanshuambuj@gmail.com\nwww.linkedin.com/in/\nambujshandil14 (LinkedIn)\ntravel-app-indus.herokuapp.com/\ncontactus (Personal)\nresume-ambuj.herokuapp.com/\nhome (Personal)\nTop Skills\nGenAi\nReactjs\nProblem Solving\nCertifications\nUnsupervised Learning,\nRecommenders, Reinforcement\nLearning\nMachine Learning\nAdvanced Learning Algorithms\nAmbuj Shandil\nLead Software Engineer | Java | Spring Boot | Angular | Exploring\nLLMs, RAG, and Agentic AI\nBengaluru, Karnataka, India\nSummary\nA seasoned full-stack developer with over a decade of expertise\nin designing and developing web applications. A passionate and\ndedicated learner, proficient in a wide array of technologies including\nJava, JavaScript, TypeScript, Python, Spring Batch, Spring MVC,\nSpring Boot, Spring JPA, Angular, ReactJS, Bootstrap, JPA,\nJDBC, Maven, Gradle, JIRA, Bitbucket, Jenkins, Git, Jest, Enzyme,\nHibernate, PCF, and more.\nCurrently exploring the cutting-edge world of Large Language\nModels (LLMs), Retrieval-Augmented Generation (RAG), and\nagentic AI, applying hands-on projects to combine my backend and\nfull-stack expertise with the latest generative AI innovations.\nExperience\nMorgan Stanley\nSenior Software Engineer\nJune 2022\xa0-\xa0Present\xa0(3 years 9 months)\nBangalore Urban, Karnataka, India\nA seasoned full-stack developer boasting over a decade of expertise in crafting\nweb applications. A passionate and dedicated learner, proficient in a wide\narray of technologies including  GenAI,  Java  ,JavaScript Spring Batch, Spring\nMVC, Spring Boot, Spring JPA, JSP, HTML5, CSS3,  Angular 13 , Bootstrap, ,\nMaven, Gradle, JIRA, Bitbucket, Jenkins, Git Hibernate, PCF, and more.\nWells Fargo\nSenior Software Engineer\nDecember 2019\xa0-\xa0June 2022\xa0(2 years 7 months)\nBengaluru, Karnataka, India\nPassionate Fullstack developer with more than 8 years of experience in\ndeveloping web applications and microservices. The primary role of developing\nmicroservices using spring boot rest, PCF, Solace, spring batch, etc. Involved\nin requirement analysis, testing, deploying the deliverables. An avid learner\n\xa0 Page 1 of 2\xa0 \xa0\nhaving hands-on in various technologies and tools like JAVA 8, JavaScript,\nSpring MVC, Spring Boot, Spring batch, JSP, REACTJS, Angular 4/5/6,\nBootstrap, JPA, JDBC, Hibernate, Maven, JIRA, Bit bucket, Jenkins, GIT, Jest,\nEnzyme, Oracle 19c, HTML5, CSS3, Junit, Mockito.\nInfosys\nTechnology Analyst\nMarch 2013\xa0-\xa0November 2019\xa0(6 years 9 months)\nBangalore, India\nPassionate Fullstack developer with more than 6 years of experience in\ndeveloping web applications. An avid learn having hands-on in various\ntechnologies and tools like JAVA 6/7/8, JavaScript, Spring portlets, Spring\nMVC, Spring Boot, Servlets, JSP, REACTJS, Angular 4/5/6, Bootstrap, JPA,\nJDBC, Hibernate, Maven, JIRA, Bit bucket, Jenkins, GIT, Jest, Enzyme,\nOpenShift, Aw ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 gr.close()
#
# AttributeError: module 'gradio' has no attribute 'close'

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'As of now, I do not hold any patents. My focus has primarily been on developing web applications and exploring emerging technologies like Large Language Models (LLMs) and agentic AI. If you have any further questions about my work or experience, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The agent correctly answers the question based on the provided context, which does not mention any patents. It also maintains a professional and engaging tone, briefly reiterating Ambuj's focus and inviting further questions, which is in line with the instructions.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
